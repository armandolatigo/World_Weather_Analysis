# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head(20)
# Out:
#     City_ID                 City Country  Max Temp Current Description  \
# 0         4           Sao Filipe      CV     76.82       broken clouds
# 1         5                Hobyo      SO     78.44     overcast clouds
# 2         7            Diebougou      BF     74.53          few clouds
# 3        10               Avarua      CK     80.65          light rain
# 4        11  Sao Raimundo Nonato      BR     77.07           clear sky
# 5        15            Busselton      AU     73.09           clear sky
# 6        16      Bambous Virieux      MU     78.22          light rain
# 7        17              Ahipara      NZ     72.01          light rain
# 8        18                 Hilo      US     80.28                mist
# 9        23           Nueva Loja      EC     71.91     overcast clouds
# 10       24               Acarau      BR     81.09    scattered clouds
# 11       29            Hithadhoo      MV     82.18     overcast clouds
# 12       31             Lorengau      PG     82.00          light rain
# 13       33              Itarema      BR     80.91    scattered clouds
# 14       38         Batemans Bay      AU     83.98    scattered clouds
# 15       39              Sambava      MG     72.86          light rain
# 16       43           San Carlos      VE     75.15    scattered clouds
# 17       46              Angoche      MZ     75.94     overcast clouds
# 18       52              Honiara      SB     83.34     overcast clouds
# 19       53              Rikitea      PF     76.57          few clouds
#
#         Lat       Lng                          Hotel Name
# 0   14.8961  -24.4956                       Hotel Xaguate
# 1    5.3505   48.5268         Halane Hotel and Restaurent
# 2   10.9667   -3.2500                   Hotel Le Consulat
# 3  -21.2078 -159.7750                        Paradise Inn
# 4   -9.0153  -42.6994                          Real Hotel
# 5  -33.6500  115.3333             Observatory Guest House
# 6  -20.3428   57.7575                      Casa Tia Villa
# 7  -35.1667  173.1667                Ahipara Holiday Park
# 8   19.7297 -155.0900                 Hilo Hawaiian Hotel
# 9    0.0847  -76.8828              Limoncocha Great Hotel
# 10  -2.8856  -40.1200                    castelo pizzaria
# 11  -0.6000   73.0833                   Scoop Guest House
# 12  -2.0226  147.2712          Lorengau Harbourside Hotel
# 13  -2.9248  -39.9167  Sea Lounge! Bar, Club & Restaurant
# 14 -35.7167  150.1833          Batemans Bay Marina Resort
# 15 -14.2667   50.1667                             Melrose
# 16   9.6612  -68.5827                   Hotel Paternopoli
# 17 -16.2325   39.9086                  Guest House HESADA
# 18  -9.4333  159.9500                 Heritage Park Hotel
# 19 -23.1203 -134.9692                     People ThankYou

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum 
     # temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df['Max Temp']
fig = gmaps.figure(center=(30.0,31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False, max_intensity=300, point_radius=4)
# 4a. Add a marker layer for each city to the map.
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
# 4b. Display the figure
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == ("Ayotzintepec")]
vacation_end = vacation_df.loc[vacation_df["City"] == ("Ayotzintepec")]
vacation_stop1 = vacation_df.loc[vacation_df['City'] == ('Puerto Escondido')]
vacation_stop2 = vacation_df.loc[vacation_df['City'] == ('Acapulco')] 
vacation_stop3 = vacation_df.loc[vacation_df['City'] == ('Lazaro Cardenas')] 

print(vacation_start)
print(vacation_end)
print(vacation_stop1)
print(vacation_stop2)
print(vacation_stop3)
# Out:
#      City_ID          City Country  Max Temp Current Description      Lat  \
# 142      447  Ayotzintepec      MX     73.38          few clouds  17.6667
#
#          Lng               Hotel Name
# 142 -96.1333  Hotel "Punta del Cerro"
#      City_ID          City Country  Max Temp Current Description      Lat  \
# 142      447  Ayotzintepec      MX     73.38          few clouds  17.6667
#
#          Lng               Hotel Name
# 142 -96.1333  Hotel "Punta del Cerro"
#      City_ID              City Country  Max Temp Current Description    Lat  \
# 102      328  Puerto Escondido      MX     83.23           clear sky  15.85
#
#          Lng                     Hotel Name
# 102 -97.0667  Aldea del Bazar Hotel and Spa
#     City_ID      City Country  Max Temp Current Description      Lat      Lng  \
# 77      253  Acapulco      MX     82.22          few clouds  16.8634 -99.8901
#
#                    Hotel Name
# 77  HS Hotsson Smart Acapulco
#      City_ID             City Country  Max Temp Current Description      Lat  \
# 218      653  Lazaro Cardenas      MX     76.37           clear sky  17.9583
#
#        Lng      Hotel Name
# 218 -102.2  quinta antigua

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy 
#    function and list indexing.
start = vacation_start['Lat'].to_numpy()[0], vacation_start['Lng'].to_numpy()[0]
end = vacation_end['Lat'].to_numpy()[0], vacation_end['Lng'].to_numpy()[0]
stop1 = vacation_stop1['Lat'].to_numpy()[0], vacation_stop1['Lng'].to_numpy()[0]
stop2 = vacation_stop2['Lat'].to_numpy()[0], vacation_stop2['Lng'].to_numpy()[0]
stop3 = vacation_stop3['Lat'].to_numpy()[0], vacation_stop3['Lng'].to_numpy()[0]

# I do not understand what the [0] does

print(start)
print(end)
print(stop1)
print(stop2)
print(stop3)
# Out:
# (17.6667, -96.1333)
# (17.6667, -96.1333)
# (15.85, -97.0667)
# (16.8634, -99.8901)
# (17.9583, -102.2)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
import gmaps.datasets
gmaps.configure(api_key = g_key)

#Latitude-Longitude pairs
start = start
stop1 = stop1
stop2 = stop2
stop3 = stop3
end = end


fig = gmaps.figure()
travel_map = gmaps.directions_layer(start, end, waypoints=[stop1,stop2, stop3], travel_mode="DRIVING")
fig.add_layer(travel_map)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3, ],ignore_index=True)
itinerary_df
# Out:
#    City_ID              City Country  Max Temp Current Description      Lat  \
# 0      447      Ayotzintepec      MX     73.38          few clouds  17.6667
# 1      328  Puerto Escondido      MX     83.23           clear sky  15.8500
# 2      253          Acapulco      MX     82.22          few clouds  16.8634
# 3      653   Lazaro Cardenas      MX     76.37           clear sky  17.9583
# 4      447      Ayotzintepec      MX     73.38          few clouds  17.6667
#
#         Lng                     Hotel Name
# 0  -96.1333        Hotel "Punta del Cerro"
# 1  -97.0667  Aldea del Bazar Hotel and Spa
# 2  -99.8901      HS Hotsson Smart Acapulco
# 3 -102.2000                 quinta antigua
# 4  -96.1333        Hotel "Punta del Cerro"

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# 11a. Add a marker layer for each city to the map.
marker_layer = gmaps.marker_layer(locations,info_box_content=hotel_info)

# 11b. Display the figure
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

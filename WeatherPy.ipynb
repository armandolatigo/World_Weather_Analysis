# %%
#pip install citipy

# %%
#import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=1500)
lngs = np.random.uniform(low=-180.000,high=180.000,size=1500)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy
 
# Create a list for holding the cities

cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 586

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
print("Hello")
# Out:
# Hello

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

#Starting URL for Weather Map API Call."
#manually enter API ...&appid= x
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid="+weather_api_key
# Create an endpoint URL for a city
city_url = url + "&q=" + "Boston"

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval   ")
print("----------------------------")

# Create counters
record_count = 1 
set_count = 1

#Loop through all the cities in our list
#for i in range(len(cities)):
    
    #Group cities in sets of 50 for logging purposes
    #if (i % 50 == 0 and i >= 50):
     #   set_count += 1
      #  record_count = 1
        #time.sleep(60)
    
    #Create endpoint URL with each city
   # city_url = url + "&q=" + cities[i]


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
#Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
           
        
        #Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
                                   
        #Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "date": city_date})
        
# If an error occurs, skip city.
    except:
        print("City not found. Skipping.....")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | saint george
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | vaitupu
# City not found. Skipping.....
# Processing Record 4 of Set 1 | lavrentiya
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | bengkulu
# Processing Record 8 of Set 1 | ribeira grande
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | san andres
# Processing Record 11 of Set 1 | merauke
# Processing Record 12 of Set 1 | leningradskiy
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | sur
# Processing Record 15 of Set 1 | taksimo
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | kismayo
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | staryy nadym
# Processing Record 20 of Set 1 | salalah
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | inhambane
# Processing Record 24 of Set 1 | barentsburg
# City not found. Skipping.....
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | arona
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | vardo
# Processing Record 31 of Set 1 | guerrero negro
# Processing Record 32 of Set 1 | grand river south east
# City not found. Skipping.....
# Processing Record 33 of Set 1 | longyearbyen
# Processing Record 34 of Set 1 | castro
# Processing Record 35 of Set 1 | ahipara
# Processing Record 36 of Set 1 | komsomolskiy
# Processing Record 37 of Set 1 | geraldton
# Processing Record 38 of Set 1 | attawapiskat
# City not found. Skipping.....
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | fengcheng
# Processing Record 41 of Set 1 | bambous virieux
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | kruisfontein
# Processing Record 44 of Set 1 | murliganj
# Processing Record 45 of Set 1 | broome
# Processing Record 46 of Set 1 | puerto leguizamo
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | chokurdakh
# Processing Record 49 of Set 1 | ormara
# Processing Record 50 of Set 1 | korla
# Processing Record 1 of Set 2 | riyadh
# Processing Record 2 of Set 2 | tawkar
# City not found. Skipping.....
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | wainwright
# Processing Record 6 of Set 2 | qaqortoq
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | madan
# Processing Record 9 of Set 2 | mae sai
# Processing Record 10 of Set 2 | redlands
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | kavieng
# Processing Record 13 of Set 2 | lolua
# City not found. Skipping.....
# Processing Record 14 of Set 2 | mutare
# Processing Record 15 of Set 2 | saskylakh
# Processing Record 16 of Set 2 | vao
# Processing Record 17 of Set 2 | bilibino
# Processing Record 18 of Set 2 | clyde river
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | severo-kurilsk
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | iqaluit
# Processing Record 23 of Set 2 | lasa
# Processing Record 24 of Set 2 | lagoa
# Processing Record 25 of Set 2 | cap malheureux
# Processing Record 26 of Set 2 | mar del plata
# Processing Record 27 of Set 2 | rudnogorsk
# Processing Record 28 of Set 2 | tumannyy
# City not found. Skipping.....
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | arraial do cabo
# Processing Record 31 of Set 2 | inndyr
# Processing Record 32 of Set 2 | lake city
# Processing Record 33 of Set 2 | xining
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | paraibano
# Processing Record 36 of Set 2 | kristiinankaupunki
# Processing Record 37 of Set 2 | umzimvubu
# City not found. Skipping.....
# Processing Record 38 of Set 2 | busselton
# Processing Record 39 of Set 2 | bima
# Processing Record 40 of Set 2 | almaznyy
# Processing Record 41 of Set 2 | husavik
# Processing Record 42 of Set 2 | nizhneyansk
# City not found. Skipping.....
# Processing Record 43 of Set 2 | tlahualilo
# City not found. Skipping.....
# Processing Record 44 of Set 2 | fairbanks
# Processing Record 45 of Set 2 | devils lake
# Processing Record 46 of Set 2 | santiago
# Processing Record 47 of Set 2 | ust-ishim
# Processing Record 48 of Set 2 | torbay
# Processing Record 49 of Set 2 | lorengau
# Processing Record 50 of Set 2 | almeirim
# Processing Record 1 of Set 3 | rio verde de mato grosso
# Processing Record 2 of Set 3 | dikson
# Processing Record 3 of Set 3 | leamington
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping.....
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | kawalu
# Processing Record 7 of Set 3 | pangoa
# Processing Record 8 of Set 3 | ha tinh
# Processing Record 9 of Set 3 | san cristobal
# Processing Record 10 of Set 3 | te anau
# Processing Record 11 of Set 3 | new norfolk
# Processing Record 12 of Set 3 | maniitsoq
# Processing Record 13 of Set 3 | aklavik
# Processing Record 14 of Set 3 | mount isa
# Processing Record 15 of Set 3 | milton
# Processing Record 16 of Set 3 | aragarcas
# Processing Record 17 of Set 3 | butaritari
# Processing Record 18 of Set 3 | tsihombe
# City not found. Skipping.....
# Processing Record 19 of Set 3 | mys shmidta
# City not found. Skipping.....
# Processing Record 20 of Set 3 | pisco
# Processing Record 21 of Set 3 | moron
# Processing Record 22 of Set 3 | angoche
# Processing Record 23 of Set 3 | taolanaro
# City not found. Skipping.....
# Processing Record 24 of Set 3 | ramnagar
# Processing Record 25 of Set 3 | oktyabrskiy
# Processing Record 26 of Set 3 | mackay
# Processing Record 27 of Set 3 | bilma
# Processing Record 28 of Set 3 | yulara
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | yellowknife
# Processing Record 31 of Set 3 | ilulissat
# Processing Record 32 of Set 3 | romitan
# Processing Record 33 of Set 3 | mehamn
# Processing Record 34 of Set 3 | gobabis
# Processing Record 35 of Set 3 | kayanga
# Processing Record 36 of Set 3 | norman wells
# Processing Record 37 of Set 3 | sitka
# Processing Record 38 of Set 3 | fortuna
# Processing Record 39 of Set 3 | cidreira
# Processing Record 40 of Set 3 | samusu
# City not found. Skipping.....
# Processing Record 41 of Set 3 | hithadhoo
# Processing Record 42 of Set 3 | pevek
# Processing Record 43 of Set 3 | belushya guba
# City not found. Skipping.....
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | burnie
# Processing Record 46 of Set 3 | kintampo
# Processing Record 47 of Set 3 | tuatapere
# Processing Record 48 of Set 3 | nueva germania
# Processing Record 49 of Set 3 | hasaki
# Processing Record 50 of Set 3 | airai
# Processing Record 1 of Set 4 | cradock
# Processing Record 2 of Set 4 | carnarvon
# Processing Record 3 of Set 4 | valkla
# Processing Record 4 of Set 4 | leh
# Processing Record 5 of Set 4 | taoudenni
# Processing Record 6 of Set 4 | hanstholm
# Processing Record 7 of Set 4 | papara
# Processing Record 8 of Set 4 | kampot
# Processing Record 9 of Set 4 | pokhara
# Processing Record 10 of Set 4 | saleaula
# City not found. Skipping.....
# Processing Record 11 of Set 4 | zhytomyr
# Processing Record 12 of Set 4 | neuquen
# Processing Record 13 of Set 4 | half moon bay
# Processing Record 14 of Set 4 | davila
# Processing Record 15 of Set 4 | diego de almagro
# Processing Record 16 of Set 4 | neiafu
# Processing Record 17 of Set 4 | khatanga
# Processing Record 18 of Set 4 | port-cartier
# Processing Record 19 of Set 4 | esperance
# Processing Record 20 of Set 4 | beringovskiy
# Processing Record 21 of Set 4 | alice springs
# Processing Record 22 of Set 4 | mercedes
# Processing Record 23 of Set 4 | kulhudhuffushi
# Processing Record 24 of Set 4 | brae
# Processing Record 25 of Set 4 | tanjong malim
# City not found. Skipping.....
# Processing Record 26 of Set 4 | byron bay
# Processing Record 27 of Set 4 | atuona
# Processing Record 28 of Set 4 | benghazi
# Processing Record 29 of Set 4 | halalo
# City not found. Skipping.....
# Processing Record 30 of Set 4 | isangel
# Processing Record 31 of Set 4 | baykalsk
# Processing Record 32 of Set 4 | sampit
# Processing Record 33 of Set 4 | sentyabrskiy
# City not found. Skipping.....
# Processing Record 34 of Set 4 | amderma
# City not found. Skipping.....
# Processing Record 35 of Set 4 | george town
# Processing Record 36 of Set 4 | vaitape
# Processing Record 37 of Set 4 | ponta do sol
# Processing Record 38 of Set 4 | ambulu
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | sidney
# Processing Record 41 of Set 4 | souillac
# Processing Record 42 of Set 4 | cocorit
# Processing Record 43 of Set 4 | kaitangata
# Processing Record 44 of Set 4 | voronovytsya
# Processing Record 45 of Set 4 | georgetown
# Processing Record 46 of Set 4 | svetlaya
# Processing Record 47 of Set 4 | oranjestad
# Processing Record 48 of Set 4 | tabuk
# Processing Record 49 of Set 4 | celestun
# Processing Record 50 of Set 4 | bonfim
# Processing Record 1 of Set 5 | port lincoln
# Processing Record 2 of Set 5 | victoria
# Processing Record 3 of Set 5 | nanortalik
# Processing Record 4 of Set 5 | sobolevo
# Processing Record 5 of Set 5 | sarakhs
# Processing Record 6 of Set 5 | egvekinot
# Processing Record 7 of Set 5 | adrar
# Processing Record 8 of Set 5 | suileng
# Processing Record 9 of Set 5 | eureka
# Processing Record 10 of Set 5 | namibe
# Processing Record 11 of Set 5 | conde
# Processing Record 12 of Set 5 | vestmannaeyjar
# Processing Record 13 of Set 5 | gamba
# Processing Record 14 of Set 5 | sosnogorsk
# Processing Record 15 of Set 5 | kemijarvi
# Processing Record 16 of Set 5 | bam
# Processing Record 17 of Set 5 | moyale
# Processing Record 18 of Set 5 | kirkwood
# Processing Record 19 of Set 5 | inawashiro
# Processing Record 20 of Set 5 | numaligarh
# Processing Record 21 of Set 5 | khandyga
# Processing Record 22 of Set 5 | tasiilaq
# Processing Record 23 of Set 5 | aykhal
# Processing Record 24 of Set 5 | texarkana
# Processing Record 25 of Set 5 | launceston
# Processing Record 26 of Set 5 | saldanha
# Processing Record 27 of Set 5 | yar-sale
# Processing Record 28 of Set 5 | nishihara
# Processing Record 29 of Set 5 | muros
# Processing Record 30 of Set 5 | rovaniemi
# Processing Record 31 of Set 5 | cheuskiny
# City not found. Skipping.....
# Processing Record 32 of Set 5 | araouane
# Processing Record 33 of Set 5 | avera
# Processing Record 34 of Set 5 | eagle pass
# Processing Record 35 of Set 5 | toliary
# City not found. Skipping.....
# Processing Record 36 of Set 5 | nouadhibou
# Processing Record 37 of Set 5 | vila velha
# Processing Record 38 of Set 5 | bansda
# City not found. Skipping.....
# Processing Record 39 of Set 5 | bandarbeyla
# Processing Record 40 of Set 5 | kodiak
# Processing Record 41 of Set 5 | ternovka
# Processing Record 42 of Set 5 | cockburn town
# Processing Record 43 of Set 5 | doba
# Processing Record 44 of Set 5 | ngunguru
# Processing Record 45 of Set 5 | kavaratti
# Processing Record 46 of Set 5 | asau
# Processing Record 47 of Set 5 | chicholi
# Processing Record 48 of Set 5 | port hardy
# Processing Record 49 of Set 5 | sudak
# Processing Record 50 of Set 5 | wahran
# City not found. Skipping.....
# Processing Record 1 of Set 6 | grand gaube
# Processing Record 2 of Set 6 | nome
# Processing Record 3 of Set 6 | ostrovnoy
# Processing Record 4 of Set 6 | teya
# Processing Record 5 of Set 6 | capitan bado
# Processing Record 6 of Set 6 | bathsheba
# Processing Record 7 of Set 6 | krasnokamensk
# Processing Record 8 of Set 6 | kieta
# Processing Record 9 of Set 6 | cherskiy
# Processing Record 10 of Set 6 | saurimo
# Processing Record 11 of Set 6 | golpayegan
# Processing Record 12 of Set 6 | ouricuri
# Processing Record 13 of Set 6 | kibala
# Processing Record 14 of Set 6 | imeni stepana razina
# Processing Record 15 of Set 6 | henties bay
# Processing Record 16 of Set 6 | ligayan
# Processing Record 17 of Set 6 | kanniyakumari
# Processing Record 18 of Set 6 | port keats
# Processing Record 19 of Set 6 | alamosa
# Processing Record 20 of Set 6 | rumuruti
# Processing Record 21 of Set 6 | pemangkat
# Processing Record 22 of Set 6 | myaundzha
# Processing Record 23 of Set 6 | tonj
# Processing Record 24 of Set 6 | bethel
# Processing Record 25 of Set 6 | constitucion
# Processing Record 26 of Set 6 | rio gallegos
# Processing Record 27 of Set 6 | holme
# Processing Record 28 of Set 6 | santa cruz de rosales
# City not found. Skipping.....
# Processing Record 29 of Set 6 | wawa
# Processing Record 30 of Set 6 | gaspe
# Processing Record 31 of Set 6 | touros
# Processing Record 32 of Set 6 | matagami
# Processing Record 33 of Set 6 | grindavik
# Processing Record 34 of Set 6 | santa maria
# Processing Record 35 of Set 6 | stanceni
# Processing Record 36 of Set 6 | kytmanovo
# Processing Record 37 of Set 6 | port-gentil
# Processing Record 38 of Set 6 | hambantota
# Processing Record 39 of Set 6 | coquimbo
# Processing Record 40 of Set 6 | talara
# Processing Record 41 of Set 6 | manzil salim
# Processing Record 42 of Set 6 | klaksvik
# Processing Record 43 of Set 6 | smithers
# Processing Record 44 of Set 6 | caravelas
# Processing Record 45 of Set 6 | grand-santi
# Processing Record 46 of Set 6 | narsaq
# Processing Record 47 of Set 6 | menongue
# Processing Record 48 of Set 6 | huntington
# Processing Record 49 of Set 6 | fomboni
# Processing Record 50 of Set 6 | santa rita do passa quatro
# Processing Record 1 of Set 7 | sioux lookout
# Processing Record 2 of Set 7 | inirida
# Processing Record 3 of Set 7 | harper
# Processing Record 4 of Set 7 | belmonte
# Processing Record 5 of Set 7 | sinnamary
# Processing Record 6 of Set 7 | broken hill
# Processing Record 7 of Set 7 | yatou
# Processing Record 8 of Set 7 | ketchikan
# Processing Record 9 of Set 7 | mount gambier
# Processing Record 10 of Set 7 | amboasary
# Processing Record 11 of Set 7 | mwanza
# Processing Record 12 of Set 7 | sawtell
# Processing Record 13 of Set 7 | nemuro
# Processing Record 14 of Set 7 | buraydah
# Processing Record 15 of Set 7 | nueva gerona
# Processing Record 16 of Set 7 | paradwip
# City not found. Skipping.....
# Processing Record 17 of Set 7 | lawrence
# Processing Record 18 of Set 7 | baykit
# Processing Record 19 of Set 7 | smolensk
# Processing Record 20 of Set 7 | noumea
# Processing Record 21 of Set 7 | kurilsk
# Processing Record 22 of Set 7 | shalya
# Processing Record 23 of Set 7 | quatre cocos
# Processing Record 24 of Set 7 | raymondville
# Processing Record 25 of Set 7 | narrabri
# Processing Record 26 of Set 7 | batagay-alyta
# Processing Record 27 of Set 7 | ziro
# Processing Record 28 of Set 7 | asosa
# Processing Record 29 of Set 7 | garissa
# Processing Record 30 of Set 7 | axim
# Processing Record 31 of Set 7 | flinders
# Processing Record 32 of Set 7 | gangotri
# City not found. Skipping.....
# Processing Record 33 of Set 7 | katsuura
# Processing Record 34 of Set 7 | buariki
# City not found. Skipping.....
# Processing Record 35 of Set 7 | hvammstangi
# City not found. Skipping.....
# Processing Record 36 of Set 7 | havre-saint-pierre
# Processing Record 37 of Set 7 | lephepe
# City not found. Skipping.....
# Processing Record 38 of Set 7 | teeli
# Processing Record 39 of Set 7 | san carlos de bariloche
# Processing Record 40 of Set 7 | xiangdong
# City not found. Skipping.....
# Processing Record 41 of Set 7 | margate
# Processing Record 42 of Set 7 | kushiro
# Processing Record 43 of Set 7 | tukrah
# Processing Record 44 of Set 7 | taburi
# City not found. Skipping.....
# Processing Record 45 of Set 7 | lazarev
# Processing Record 46 of Set 7 | udachnyy
# Processing Record 47 of Set 7 | kitgum
# Processing Record 48 of Set 7 | sao felix do xingu
# Processing Record 49 of Set 7 | itoman
# Processing Record 50 of Set 7 | port augusta
# Processing Record 1 of Set 8 | padang
# Processing Record 2 of Set 8 | sao joao da barra
# Processing Record 3 of Set 8 | olafsvik
# Processing Record 4 of Set 8 | codrington
# Processing Record 5 of Set 8 | abu dhabi
# Processing Record 6 of Set 8 | muisne
# Processing Record 7 of Set 8 | tilichiki
# Processing Record 8 of Set 8 | tambacounda
# Processing Record 9 of Set 8 | dong xoai
# Processing Record 10 of Set 8 | hamilton
# Processing Record 11 of Set 8 | seymchan
# Processing Record 12 of Set 8 | paamiut
# Processing Record 13 of Set 8 | nelson bay
# Processing Record 14 of Set 8 | bratislava
# Processing Record 15 of Set 8 | chuy
# Processing Record 16 of Set 8 | san clemente
# Processing Record 17 of Set 8 | kihei
# Processing Record 18 of Set 8 | bana
# Processing Record 19 of Set 8 | aasiaat
# Processing Record 20 of Set 8 | lidzbark warminski
# Processing Record 21 of Set 8 | denpasar
# Processing Record 22 of Set 8 | nuevo casas grandes
# Processing Record 23 of Set 8 | ambilobe
# Processing Record 24 of Set 8 | vila franca do campo
# Processing Record 25 of Set 8 | ondorhaan
# City not found. Skipping.....
# Processing Record 26 of Set 8 | ixtapa
# Processing Record 27 of Set 8 | ust-kuyga
# Processing Record 28 of Set 8 | port hedland
# Processing Record 29 of Set 8 | bela
# Processing Record 30 of Set 8 | banjar
# Processing Record 31 of Set 8 | monrovia
# Processing Record 32 of Set 8 | evensk
# Processing Record 33 of Set 8 | huarmey
# Processing Record 34 of Set 8 | san patricio
# Processing Record 35 of Set 8 | sorong
# Processing Record 36 of Set 8 | koslan
# Processing Record 37 of Set 8 | great yarmouth
# Processing Record 38 of Set 8 | iskateley
# Processing Record 39 of Set 8 | dali
# Processing Record 40 of Set 8 | marsh harbour
# Processing Record 41 of Set 8 | yeletskiy
# City not found. Skipping.....
# Processing Record 42 of Set 8 | palmer
# Processing Record 43 of Set 8 | upernavik
# Processing Record 44 of Set 8 | luwuk
# Processing Record 45 of Set 8 | sao filipe
# Processing Record 46 of Set 8 | ilhabela
# Processing Record 47 of Set 8 | ovalle
# Processing Record 48 of Set 8 | belyy yar
# Processing Record 49 of Set 8 | georgiyevka
# Processing Record 50 of Set 8 | oussouye
# Processing Record 1 of Set 9 | baherden
# Processing Record 2 of Set 9 | fort-shevchenko
# Processing Record 3 of Set 9 | baruun-urt
# Processing Record 4 of Set 9 | plunge
# Processing Record 5 of Set 9 | hebertville
# City not found. Skipping.....
# Processing Record 6 of Set 9 | brajrajnagar
# City not found. Skipping.....
# Processing Record 7 of Set 9 | hofn
# Processing Record 8 of Set 9 | beni
# Processing Record 9 of Set 9 | saryshagan
# City not found. Skipping.....
# Processing Record 10 of Set 9 | akyab
# Processing Record 11 of Set 9 | pradopolis
# Processing Record 12 of Set 9 | snasa
# Processing Record 13 of Set 9 | shakawe
# Processing Record 14 of Set 9 | provideniya
# Processing Record 15 of Set 9 | fairview
# Processing Record 16 of Set 9 | laguna
# Processing Record 17 of Set 9 | great falls
# Processing Record 18 of Set 9 | fengkou
# Processing Record 19 of Set 9 | alice
# Processing Record 20 of Set 9 | prince rupert
# Processing Record 21 of Set 9 | polovinnoye
# Processing Record 22 of Set 9 | thessalon
# Processing Record 23 of Set 9 | bay roberts
# Processing Record 24 of Set 9 | miraflores
# Processing Record 25 of Set 9 | warqla
# City not found. Skipping.....
# Processing Record 26 of Set 9 | dongsheng
# Processing Record 27 of Set 9 | tiksi
# Processing Record 28 of Set 9 | nizhnyaya pavlovka
# City not found. Skipping.....
# Processing Record 29 of Set 9 | dzaoudzi
# Processing Record 30 of Set 9 | cayenne
# Processing Record 31 of Set 9 | umm lajj
# Processing Record 32 of Set 9 | los alamos
# Processing Record 33 of Set 9 | lompoc
# Processing Record 34 of Set 9 | okhotsk
# Processing Record 35 of Set 9 | ballina
# Processing Record 36 of Set 9 | corn island
# Processing Record 37 of Set 9 | pecos
# Processing Record 38 of Set 9 | alofi
# Processing Record 39 of Set 9 | the valley
# Processing Record 40 of Set 9 | garden city
# Processing Record 41 of Set 9 | burica
# City not found. Skipping.....
# Processing Record 42 of Set 9 | san vicente
# Processing Record 43 of Set 9 | cunha
# Processing Record 44 of Set 9 | mayo
# Processing Record 45 of Set 9 | la rioja
# Processing Record 46 of Set 9 | fuzhou
# Processing Record 47 of Set 9 | svetlogorsk
# Processing Record 48 of Set 9 | toktogul
# Processing Record 49 of Set 9 | meulaboh
# Processing Record 50 of Set 9 | paita
# Processing Record 1 of Set 10 | chingirlau
# Processing Record 2 of Set 10 | mersing
# Processing Record 3 of Set 10 | urdzhar
# City not found. Skipping.....
# Processing Record 4 of Set 10 | kodinsk
# Processing Record 5 of Set 10 | zyryanka
# Processing Record 6 of Set 10 | oga
# Processing Record 7 of Set 10 | sindor
# Processing Record 8 of Set 10 | catalina
# Processing Record 9 of Set 10 | san quintin
# Processing Record 10 of Set 10 | srednekolymsk
# Processing Record 11 of Set 10 | shubarshi
# Processing Record 12 of Set 10 | alampur
# Processing Record 13 of Set 10 | talnakh
# Processing Record 14 of Set 10 | warrington
# Processing Record 15 of Set 10 | santa isabel do rio negro
# Processing Record 16 of Set 10 | kot diji
# Processing Record 17 of Set 10 | tarrafal
# Processing Record 18 of Set 10 | muswellbrook
# Processing Record 19 of Set 10 | sokolo
# Processing Record 20 of Set 10 | marcona
# City not found. Skipping.....
# Processing Record 21 of Set 10 | sembakung
# Processing Record 22 of Set 10 | el tigre
# Processing Record 23 of Set 10 | saint-medard-en-jalles
# Processing Record 24 of Set 10 | lebu
# Processing Record 25 of Set 10 | sawakin
# Processing Record 26 of Set 10 | fonte boa
# Processing Record 27 of Set 10 | gushikawa
# Processing Record 28 of Set 10 | robe
# Processing Record 29 of Set 10 | atar
# Processing Record 30 of Set 10 | bargal
# City not found. Skipping.....
# Processing Record 31 of Set 10 | palabuhanratu
# City not found. Skipping.....
# Processing Record 32 of Set 10 | sesheke
# Processing Record 33 of Set 10 | chara
# Processing Record 34 of Set 10 | sohbatpur
# Processing Record 35 of Set 10 | carauari
# Processing Record 36 of Set 10 | rabo de peixe
# Processing Record 37 of Set 10 | phek
# Processing Record 38 of Set 10 | mufumbwe
# Processing Record 39 of Set 10 | mizdah
# Processing Record 40 of Set 10 | sao joao do piaui
# Processing Record 41 of Set 10 | port macquarie
# Processing Record 42 of Set 10 | marzuq
# Processing Record 43 of Set 10 | hami
# Processing Record 44 of Set 10 | leshukonskoye
# Processing Record 45 of Set 10 | anloga
# Processing Record 46 of Set 10 | pilar
# Processing Record 47 of Set 10 | northam
# Processing Record 48 of Set 10 | sisimiut
# Processing Record 49 of Set 10 | teguise
# Processing Record 50 of Set 10 | mali
# Processing Record 1 of Set 11 | pangnirtung
# Processing Record 2 of Set 11 | tigre
# Processing Record 3 of Set 11 | omsukchan
# Processing Record 4 of Set 11 | santa rosa
# Processing Record 5 of Set 11 | samarai
# Processing Record 6 of Set 11 | ardrishaig
# Processing Record 7 of Set 11 | aksay
# Processing Record 8 of Set 11 | piacabucu
# Processing Record 9 of Set 11 | port said
# Processing Record 10 of Set 11 | caronport
# Processing Record 11 of Set 11 | katobu
# Processing Record 12 of Set 11 | osterburg
# Processing Record 13 of Set 11 | tambul
# City not found. Skipping.....
# Processing Record 14 of Set 11 | pangkalanbuun
# Processing Record 15 of Set 11 | kusk
# City not found. Skipping.....
# Processing Record 16 of Set 11 | dobrinka
# Processing Record 17 of Set 11 | san policarpo
# Processing Record 18 of Set 11 | zimovniki
# Processing Record 19 of Set 11 | twin falls
# Processing Record 20 of Set 11 | guarapari
# Processing Record 21 of Set 11 | cascais
# Processing Record 22 of Set 11 | hosbach
# Processing Record 23 of Set 11 | shelburne
# Processing Record 24 of Set 11 | springbok
# Processing Record 25 of Set 11 | carson city
# Processing Record 26 of Set 11 | ponta delgada
# Processing Record 27 of Set 11 | marystown
# Processing Record 28 of Set 11 | toyooka
# Processing Record 29 of Set 11 | high level
# Processing Record 30 of Set 11 | bundaberg
# Processing Record 31 of Set 11 | mahajanga
# Processing Record 32 of Set 11 | aswan
# Processing Record 33 of Set 11 | lively
# Processing Record 34 of Set 11 | khartoum
# Processing Record 35 of Set 11 | straumen
# Processing Record 36 of Set 11 | rincon
# Processing Record 37 of Set 11 | tokur
# Processing Record 38 of Set 11 | sebinkarahisar
# Processing Record 39 of Set 11 | evanston
# Processing Record 40 of Set 11 | port blair
# Processing Record 41 of Set 11 | polunochnoye
# Processing Record 42 of Set 11 | nuuk
# Processing Record 43 of Set 11 | rondonopolis
# Processing Record 44 of Set 11 | carutapera
# Processing Record 45 of Set 11 | ust-tsilma
# Processing Record 46 of Set 11 | sabang
# Processing Record 47 of Set 11 | ngukurr
# City not found. Skipping.....
# Processing Record 48 of Set 11 | mingyue
# Processing Record 49 of Set 11 | boyolangu
# Processing Record 50 of Set 11 | arlit
# Processing Record 1 of Set 12 | waddan
# Processing Record 2 of Set 12 | urulga
# City not found. Skipping.....
# Processing Record 3 of Set 12 | maniwaki
# Processing Record 4 of Set 12 | arman
# Processing Record 5 of Set 12 | bur gabo
# City not found. Skipping.....
# Processing Record 6 of Set 12 | hanusovice
# Processing Record 7 of Set 12 | london
# Processing Record 8 of Set 12 | louisbourg
# City not found. Skipping.....
# Processing Record 9 of Set 12 | at-bashi
# Processing Record 10 of Set 12 | koungheul
# Processing Record 11 of Set 12 | ozernovskiy
# Processing Record 12 of Set 12 | mangai
# Processing Record 13 of Set 12 | banda aceh
# Processing Record 14 of Set 12 | ambatolampy
# Processing Record 15 of Set 12 | tambopata
# Processing Record 16 of Set 12 | palauig
# Processing Record 17 of Set 12 | micheweni
# Processing Record 18 of Set 12 | chernyshevskiy
# Processing Record 19 of Set 12 | berlevag
# Processing Record 20 of Set 12 | jabinyanah
# Processing Record 21 of Set 12 | vizantea
# City not found. Skipping.....
# Processing Record 22 of Set 12 | coahuayana
# Processing Record 23 of Set 12 | acapulco
# Processing Record 24 of Set 12 | kamenskoye
# City not found. Skipping.....
# Processing Record 25 of Set 12 | ust-kut
# Processing Record 26 of Set 12 | lososina
# Processing Record 27 of Set 12 | roald
# Processing Record 28 of Set 12 | mogadishu
# Processing Record 29 of Set 12 | kedrovyy
# Processing Record 30 of Set 12 | krasnoselkup
# Processing Record 31 of Set 12 | batemans bay
# Processing Record 32 of Set 12 | mandera
# Processing Record 33 of Set 12 | sorvag
# City not found. Skipping.....
# Processing Record 34 of Set 12 | contamana
# Processing Record 35 of Set 12 | mafinga
# Processing Record 36 of Set 12 | toucheng
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Saint George  37.1041 -113.5841     66.67        33           1
# 1         Rikitea -23.1203 -134.9692     75.72        74          99
# 2      Lavrentiya  65.5833 -171.0000     -2.51        93         100
# 3       Jamestown  42.0970  -79.2353     42.39        88          90
# 4         Mataura -46.1927  168.8643     50.49        72           6
# 5        Bengkulu  -3.8004  102.2655     75.45        89         100
# 6  Ribeira Grande  38.5167  -28.7000     64.80        68          75
# 7       Mahebourg -20.4081   57.7000     79.25        73          20
# 8      San Andres  12.5847  -81.7006     86.02        70          20
# 9         Merauke  -8.4667  140.3333     79.34        78         100
#
#    Wind Speed Country                date
# 0        0.00      US  2021-1206 18:51:50
# 1        6.93      PF  2021-1206 18:55:36
# 2       10.45      RU  2021-1206 18:55:37
# 3       13.00      US  2021-1206 18:51:15
# 4        4.27      NZ  2021-1206 18:55:37
# 5        4.54      ID  2021-1206 18:55:37
# 6       16.11      PT  2021-1206 18:55:38
# 7        9.22      MU  2021-1206 18:55:07
# 8       14.97      CO  2021-1206 18:55:38
# 9        4.59      ID  2021-1206 18:55:05

# %%
new_column_order = ['City', 'Country', 'date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df.head(15)
# Out:
#               City Country                date      Lat       Lng  Max Temp  \
# 0     Saint George      US  2021-1206 18:51:50  37.1041 -113.5841     66.67
# 1          Rikitea      PF  2021-1206 18:55:36 -23.1203 -134.9692     75.72
# 2       Lavrentiya      RU  2021-1206 18:55:37  65.5833 -171.0000     -2.51
# 3        Jamestown      US  2021-1206 18:51:15  42.0970  -79.2353     42.39
# 4          Mataura      NZ  2021-1206 18:55:37 -46.1927  168.8643     50.49
# 5         Bengkulu      ID  2021-1206 18:55:37  -3.8004  102.2655     75.45
# 6   Ribeira Grande      PT  2021-1206 18:55:38  38.5167  -28.7000     64.80
# 7        Mahebourg      MU  2021-1206 18:55:07 -20.4081   57.7000     79.25
# 8       San Andres      CO  2021-1206 18:55:38  12.5847  -81.7006     86.02
# 9          Merauke      ID  2021-1206 18:55:05  -8.4667  140.3333     79.34
# 10   Leningradskiy      RU  2021-1206 18:55:38  69.3833  178.4167     -6.61
# 11         Ushuaia      AR  2021-1206 18:55:39 -54.8000  -68.3000     51.46
# 12             Sur      OM  2021-1206 18:55:39  22.5667   59.5289     72.99
# 13         Taksimo      RU  2021-1206 18:55:39  56.3444  114.8794      3.43
# 14     Port Alfred      ZA  2021-1206 18:54:10 -33.5906   26.8910     65.21
#
#     Humidity  Cloudiness  Wind Speed
# 0         33           1        0.00
# 1         74          99        6.93
# 2         93         100       10.45
# 3         88          90       13.00
# 4         72           6        4.27
# 5         89         100        4.54
# 6         68          75       16.11
# 7         73          20        9.22
# 8         70          20       14.97
# 9         78         100        4.59
# 10        89         100       26.33
# 11        58          75       23.02
# 12        64           0        5.03
# 13        96          99        0.72
# 14        86          59        9.19

# %%
import os
cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in '/Users/armandolatigo/Desktop/Analysis Projects/World_Weather_Analysis': ['.DS_Store', 'config.py', '__pycache__', 'README.md', 'random_numbers.ipynb', '.gitignore', 'weather_data', 'WeatherPy.ipynb', '.ipynb_checkpoints', '.git', 'API_Practice.ipynb']

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting
lats = city_data_df['Lat']
max_temps = city_data_df['Max Temp']
humidity = city_data_df['Humidity']
cloudiness = city_data_df['Cloudiness']
wind_speed = city_data_df['Wind Speed']

# %%
# Import the time module
import time

# Build the scatetr plot for latitude vs max temperature
plt.scatter(lats, max_temps,
            edgecolor = 'k',
            linewidths = 1,
            marker = 'o',
            alpha = 0.8,
            label = 'cities')

#Incorporate the graph properties.
plt.title(f'City Latitude vs Max Temperature ' + time.strftime("%x"))
plt.ylabel("Max Temperature")
plt.xlabel("Latitude")
plt.grid(True)

#Save the figure
plt.savefig("weather_data/Fig1.png")

#Show Figure
plt.show()

# %%
# Build the scatetr plot for latitude vs humidity
plt.scatter(lats, humidity,
            edgecolor = 'k',
            linewidths = 1,
            marker = 'o',
            alpha = 0.8,
            label = 'cities')

#Incorporate the graph properties.
plt.title(f'City Latitude vs Humidity ' + time.strftime("%x"))
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

#Save the figure
plt.savefig("weather_data/Fig2.png")

#Show Figure
plt.show()

# %%
# Build the scatetr plot for latitude vs max temperature
plt.scatter(lats, cloudiness,
            edgecolor = 'k',
            linewidths = 1,
            marker = 'o',
            alpha = 0.8,
            label = 'cities')

#Incorporate the graph properties.
plt.title(f'City Latitude vs Cloudiness ' + time.strftime("%x"))
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

#Save the figure
plt.savefig("weather_data/Fig3.png")

#Show Figure
plt.show()

# %%
#Build the scatter plots for latitude vs. wind speed
plt.scatter(lats,wind_speed,
            edgecolor = 'k',
            linewidths = 1,
            marker = 'o',
            alpha = 0.8,
            label = 'cities')

#Incorporate the graph properties
plt.title('City Latitude vs Wind Speed ' + time.strftime('%x'))
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('weather_data/Fig4.png')
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
from scipy.stats import linregress

# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
     # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                     Taksimo
# Country                       RU
# date          2021-1206 18:55:39
# Lat                      56.3444
# Lng                     114.8794
# Max Temp                    3.43
# Humidity                      96
# Cloudiness                    99
# Wind Speed                  0.72
# Name: 13, dtype: object

# %%
city_data_df['Lat'] >= 0
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 527    False
# 528     True
# 529    False
# 530    False
# 531     True
# Name: Lat, Length: 532, dtype: bool

# %%
city_data_df.loc[(city_data_df['Lat'] >= 0)].head()
# Out:
#              City Country                date      Lat       Lng  Max Temp  \
# 0    Saint George      US  2021-1206 18:51:50  37.1041 -113.5841     66.67
# 2      Lavrentiya      RU  2021-1206 18:55:37  65.5833 -171.0000     -2.51
# 3       Jamestown      US  2021-1206 18:51:15  42.0970  -79.2353     42.39
# 6  Ribeira Grande      PT  2021-1206 18:55:38  38.5167  -28.7000     64.80
# 8      San Andres      CO  2021-1206 18:55:38  12.5847  -81.7006     86.02
#
#    Humidity  Cloudiness  Wind Speed
# 0        33           1        0.00
# 2        93         100       10.45
# 3        88          90       13.00
# 6        68          75       16.11
# 8        70          20       14.97

# %%
northern_hemi_df = city_data_df.loc[(city_data_df['Lat'] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df['Lat'] < 0)]

# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor Maximum Temperature',
                       'Max Temp',(3,-45))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor Maximum Temperature',
                       'Max Temp',(-55,37))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

#Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the northern Hemisphere \nfor % Humidity',
                       '% Humidity',(40,10))

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Humidity',
                       '% Humidity',(-55,15))

# %%
#skilldrill 6.4.4

#Southern Hemisphere Cloudiness
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Cloudiness',
                       '% Cloudiness',(-55,15))

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Cloudiness',
                       '% Cloudiness',(40,20))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor Wind Speed', 
                       'Wind Speed',(40,35))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor Wind Speed', 
                       'Wind Speed',(-25,25))

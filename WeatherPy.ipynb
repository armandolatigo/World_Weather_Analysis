# %%
#pip install citipy

# %%
#import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=1500)
lngs = np.random.uniform(low=-180.000,high=180.000,size=1500)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy
 
# Create a list for holding the cities

cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 624

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
print("Hello")
# Out:
# Hello

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

#Starting URL for Weather Map API Call."
#manually enter API ...&appid= x
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid="+weather_api_key
# Create an endpoint URL for a city
city_url = url + "&q=" + "Boston"

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval   ")
print("----------------------------")

# Create counters
record_count = 1 
set_count = 1

#Loop through all the cities in our list
#for i in range(len(cities)):
    
    #Group cities in sets of 50 for logging purposes
    #if (i % 50 == 0 and i >= 50):
     #   set_count += 1
      #  record_count = 1
        #time.sleep(60)
    
    #Create endpoint URL with each city
   # city_url = url + "&q=" + cities[i]


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
#Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
           
        
        #Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
                                   
        #Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "date": city_date})
        
# If an error occurs, skip city.
    except:
        print("City not found. Skipping.....")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | nantucket
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | erice
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | mar del plata
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | amderma
# City not found. Skipping.....
# Processing Record 10 of Set 1 | fortuna
# Processing Record 11 of Set 1 | taburi
# City not found. Skipping.....
# Processing Record 12 of Set 1 | asfi
# Processing Record 13 of Set 1 | okakarara
# Processing Record 14 of Set 1 | luanda
# Processing Record 15 of Set 1 | atambua
# Processing Record 16 of Set 1 | jatai
# Processing Record 17 of Set 1 | folkestone
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping.....
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | solnechnyy
# Processing Record 21 of Set 1 | hami
# Processing Record 22 of Set 1 | tuktoyaktuk
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | blackwater
# Processing Record 25 of Set 1 | vaitupu
# City not found. Skipping.....
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | esperance
# Processing Record 30 of Set 1 | mpanda
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping.....
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | ngaoundere
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | northam
# Processing Record 36 of Set 1 | souillac
# Processing Record 37 of Set 1 | tumannyy
# City not found. Skipping.....
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | haines junction
# Processing Record 40 of Set 1 | panaba
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | isangel
# Processing Record 43 of Set 1 | hokitika
# Processing Record 44 of Set 1 | yumen
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | attawapiskat
# City not found. Skipping.....
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | torbay
# Processing Record 5 of Set 2 | nizhneyansk
# City not found. Skipping.....
# Processing Record 6 of Set 2 | nelson bay
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | coihaique
# Processing Record 9 of Set 2 | mahebourg
# Processing Record 10 of Set 2 | bima
# Processing Record 11 of Set 2 | moyobamba
# Processing Record 12 of Set 2 | mandalgovi
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | vestmanna
# Processing Record 16 of Set 2 | kracheh
# City not found. Skipping.....
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | yarada
# Processing Record 19 of Set 2 | saskylakh
# Processing Record 20 of Set 2 | nanortalik
# Processing Record 21 of Set 2 | muros
# Processing Record 22 of Set 2 | te anau
# Processing Record 23 of Set 2 | baracoa
# Processing Record 24 of Set 2 | aklavik
# Processing Record 25 of Set 2 | aquidauana
# Processing Record 26 of Set 2 | sur
# Processing Record 27 of Set 2 | tasiilaq
# Processing Record 28 of Set 2 | manama
# Processing Record 29 of Set 2 | camabatela
# Processing Record 30 of Set 2 | progreso
# Processing Record 31 of Set 2 | tsihombe
# City not found. Skipping.....
# Processing Record 32 of Set 2 | castro
# Processing Record 33 of Set 2 | valleyview
# Processing Record 34 of Set 2 | ponta do sol
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | kamenka
# Processing Record 37 of Set 2 | beringovskiy
# Processing Record 38 of Set 2 | palmer
# Processing Record 39 of Set 2 | bathsheba
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | ribeira grande
# Processing Record 42 of Set 2 | brae
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | saint-louis
# Processing Record 45 of Set 2 | cardoso
# Processing Record 46 of Set 2 | gravdal
# Processing Record 47 of Set 2 | vila franca do campo
# Processing Record 48 of Set 2 | samarai
# Processing Record 49 of Set 2 | bilma
# Processing Record 50 of Set 2 | christchurch
# Processing Record 1 of Set 3 | svetlogorsk
# Processing Record 2 of Set 3 | hithadhoo
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | palestina
# Processing Record 5 of Set 3 | cherskiy
# Processing Record 6 of Set 3 | ambon
# Processing Record 7 of Set 3 | jambi
# Processing Record 8 of Set 3 | huron
# Processing Record 9 of Set 3 | oussouye
# Processing Record 10 of Set 3 | narsaq
# Processing Record 11 of Set 3 | avarua
# Processing Record 12 of Set 3 | fort nelson
# Processing Record 13 of Set 3 | pangody
# Processing Record 14 of Set 3 | east london
# Processing Record 15 of Set 3 | glodeni
# Processing Record 16 of Set 3 | provideniya
# Processing Record 17 of Set 3 | airai
# Processing Record 18 of Set 3 | chuy
# Processing Record 19 of Set 3 | laguna
# Processing Record 20 of Set 3 | kalmunai
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping.....
# Processing Record 22 of Set 3 | ocampo
# Processing Record 23 of Set 3 | khor
# Processing Record 24 of Set 3 | kerki
# City not found. Skipping.....
# Processing Record 25 of Set 3 | jieshi
# Processing Record 26 of Set 3 | taltal
# Processing Record 27 of Set 3 | geraldton
# Processing Record 28 of Set 3 | skibbereen
# Processing Record 29 of Set 3 | roma
# Processing Record 30 of Set 3 | faya
# Processing Record 31 of Set 3 | mago
# Processing Record 32 of Set 3 | palasa
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | ust-maya
# Processing Record 35 of Set 3 | fethiye
# Processing Record 36 of Set 3 | san patricio
# Processing Record 37 of Set 3 | port macquarie
# Processing Record 38 of Set 3 | daryapur
# Processing Record 39 of Set 3 | puerto ayora
# Processing Record 40 of Set 3 | soc trang
# Processing Record 41 of Set 3 | shimoda
# Processing Record 42 of Set 3 | ostrovnoy
# Processing Record 43 of Set 3 | tuatapere
# Processing Record 44 of Set 3 | san felipe
# Processing Record 45 of Set 3 | lakatoro
# Processing Record 46 of Set 3 | anloga
# Processing Record 47 of Set 3 | lavrentiya
# Processing Record 48 of Set 3 | vila velha
# Processing Record 49 of Set 3 | yulara
# Processing Record 50 of Set 3 | bethel
# Processing Record 1 of Set 4 | sept-iles
# Processing Record 2 of Set 4 | houston
# Processing Record 3 of Set 4 | victoria
# Processing Record 4 of Set 4 | xining
# Processing Record 5 of Set 4 | saint anthony
# Processing Record 6 of Set 4 | zambezi
# Processing Record 7 of Set 4 | norman wells
# Processing Record 8 of Set 4 | tonj
# Processing Record 9 of Set 4 | abu samrah
# Processing Record 10 of Set 4 | faanui
# Processing Record 11 of Set 4 | el rosario
# Processing Record 12 of Set 4 | oktyabrskoye
# Processing Record 13 of Set 4 | rawson
# Processing Record 14 of Set 4 | cristinapolis
# Processing Record 15 of Set 4 | kayerkan
# Processing Record 16 of Set 4 | namatanai
# Processing Record 17 of Set 4 | klaksvik
# Processing Record 18 of Set 4 | labytnangi
# Processing Record 19 of Set 4 | angelokhorion
# City not found. Skipping.....
# Processing Record 20 of Set 4 | luderitz
# Processing Record 21 of Set 4 | krasnoselkup
# Processing Record 22 of Set 4 | timbiqui
# Processing Record 23 of Set 4 | katsuura
# Processing Record 24 of Set 4 | gobabis
# Processing Record 25 of Set 4 | marystown
# Processing Record 26 of Set 4 | tome-acu
# City not found. Skipping.....
# Processing Record 27 of Set 4 | barrow
# Processing Record 28 of Set 4 | sogdiondon
# City not found. Skipping.....
# Processing Record 29 of Set 4 | lamu
# Processing Record 30 of Set 4 | yemelyanovo
# Processing Record 31 of Set 4 | vestmannaeyjar
# Processing Record 32 of Set 4 | axim
# Processing Record 33 of Set 4 | foki
# Processing Record 34 of Set 4 | oeiras do para
# Processing Record 35 of Set 4 | matara
# Processing Record 36 of Set 4 | clyde river
# Processing Record 37 of Set 4 | santiago del estero
# Processing Record 38 of Set 4 | kumo
# Processing Record 39 of Set 4 | baykit
# Processing Record 40 of Set 4 | xinzhi
# Processing Record 41 of Set 4 | raudeberg
# Processing Record 42 of Set 4 | jadu
# Processing Record 43 of Set 4 | wairoa
# Processing Record 44 of Set 4 | angoram
# Processing Record 45 of Set 4 | ixtapa
# Processing Record 46 of Set 4 | borogontsy
# Processing Record 47 of Set 4 | tabiauea
# City not found. Skipping.....
# Processing Record 48 of Set 4 | tawkar
# City not found. Skipping.....
# Processing Record 49 of Set 4 | barentsburg
# City not found. Skipping.....
# Processing Record 50 of Set 4 | cidreira
# Processing Record 1 of Set 5 | ekhabi
# Processing Record 2 of Set 5 | halifax
# Processing Record 3 of Set 5 | bambous virieux
# Processing Record 4 of Set 5 | hofn
# Processing Record 5 of Set 5 | ondorhaan
# City not found. Skipping.....
# Processing Record 6 of Set 5 | saleaula
# City not found. Skipping.....
# Processing Record 7 of Set 5 | khatanga
# Processing Record 8 of Set 5 | oktyabrskiy
# Processing Record 9 of Set 5 | bukachacha
# Processing Record 10 of Set 5 | bondo
# Processing Record 11 of Set 5 | atar
# Processing Record 12 of Set 5 | touros
# Processing Record 13 of Set 5 | carhuamayo
# Processing Record 14 of Set 5 | ulkan
# Processing Record 15 of Set 5 | martil
# Processing Record 16 of Set 5 | lithgow
# Processing Record 17 of Set 5 | salalah
# Processing Record 18 of Set 5 | huilong
# Processing Record 19 of Set 5 | kilakarai
# Processing Record 20 of Set 5 | rocha
# Processing Record 21 of Set 5 | kahului
# Processing Record 22 of Set 5 | mergui
# City not found. Skipping.....
# Processing Record 23 of Set 5 | tambovka
# Processing Record 24 of Set 5 | naze
# Processing Record 25 of Set 5 | port augusta
# Processing Record 26 of Set 5 | sonoita
# Processing Record 27 of Set 5 | lagoa
# Processing Record 28 of Set 5 | rudnogorsk
# Processing Record 29 of Set 5 | kruisfontein
# Processing Record 30 of Set 5 | pudozh
# Processing Record 31 of Set 5 | bengkulu
# Processing Record 32 of Set 5 | comodoro rivadavia
# Processing Record 33 of Set 5 | kerema
# Processing Record 34 of Set 5 | port lincoln
# Processing Record 35 of Set 5 | cayenne
# Processing Record 36 of Set 5 | acarau
# Processing Record 37 of Set 5 | chicama
# Processing Record 38 of Set 5 | chokurdakh
# Processing Record 39 of Set 5 | bogen
# Processing Record 40 of Set 5 | pocone
# Processing Record 41 of Set 5 | biograd na moru
# Processing Record 42 of Set 5 | mgandu
# Processing Record 43 of Set 5 | berlevag
# Processing Record 44 of Set 5 | tiksi
# Processing Record 45 of Set 5 | belaya gora
# Processing Record 46 of Set 5 | north platte
# Processing Record 47 of Set 5 | bocaranga
# City not found. Skipping.....
# Processing Record 48 of Set 5 | bibai
# Processing Record 49 of Set 5 | praia da vitoria
# Processing Record 50 of Set 5 | spornoye
# Processing Record 1 of Set 6 | yabelo
# Processing Record 2 of Set 6 | camana
# Processing Record 3 of Set 6 | la ronge
# Processing Record 4 of Set 6 | fairbanks
# Processing Record 5 of Set 6 | yerbogachen
# Processing Record 6 of Set 6 | rapid valley
# Processing Record 7 of Set 6 | ulladulla
# Processing Record 8 of Set 6 | darnah
# Processing Record 9 of Set 6 | hellevoetsluis
# Processing Record 10 of Set 6 | severo-kurilsk
# Processing Record 11 of Set 6 | hamilton
# Processing Record 12 of Set 6 | coquimbo
# Processing Record 13 of Set 6 | karauzyak
# City not found. Skipping.....
# Processing Record 14 of Set 6 | bubaque
# Processing Record 15 of Set 6 | kirakira
# Processing Record 16 of Set 6 | codrington
# Processing Record 17 of Set 6 | chagda
# City not found. Skipping.....
# Processing Record 18 of Set 6 | mbanza-ngungu
# Processing Record 19 of Set 6 | manoel urbano
# Processing Record 20 of Set 6 | cabo san lucas
# Processing Record 21 of Set 6 | saint-francois
# Processing Record 22 of Set 6 | nieves
# Processing Record 23 of Set 6 | sterlibashevo
# Processing Record 24 of Set 6 | padang
# Processing Record 25 of Set 6 | gunjur
# Processing Record 26 of Set 6 | kaeo
# Processing Record 27 of Set 6 | nianzishan
# Processing Record 28 of Set 6 | ahipara
# Processing Record 29 of Set 6 | boguchany
# Processing Record 30 of Set 6 | kathu
# Processing Record 31 of Set 6 | inderborskiy
# City not found. Skipping.....
# Processing Record 32 of Set 6 | fomboni
# Processing Record 33 of Set 6 | mayo
# Processing Record 34 of Set 6 | maksatikha
# Processing Record 35 of Set 6 | lumatil
# Processing Record 36 of Set 6 | shizukuishi
# Processing Record 37 of Set 6 | tecoanapa
# Processing Record 38 of Set 6 | yilan
# Processing Record 39 of Set 6 | brewster
# Processing Record 40 of Set 6 | nikolskoye
# Processing Record 41 of Set 6 | tefe
# Processing Record 42 of Set 6 | aplahoue
# Processing Record 43 of Set 6 | chiredzi
# Processing Record 44 of Set 6 | guerrero negro
# Processing Record 45 of Set 6 | carinhanha
# Processing Record 46 of Set 6 | nguiu
# City not found. Skipping.....
# Processing Record 47 of Set 6 | nome
# Processing Record 48 of Set 6 | puerto colombia
# Processing Record 49 of Set 6 | nizhnyaya tavda
# Processing Record 50 of Set 6 | borovichi
# Processing Record 1 of Set 7 | taunggyi
# Processing Record 2 of Set 7 | kloulklubed
# Processing Record 3 of Set 7 | kaitangata
# Processing Record 4 of Set 7 | luganville
# Processing Record 5 of Set 7 | maniitsoq
# Processing Record 6 of Set 7 | tessalit
# Processing Record 7 of Set 7 | ca mau
# Processing Record 8 of Set 7 | mount isa
# Processing Record 9 of Set 7 | mchinji
# Processing Record 10 of Set 7 | boyuibe
# Processing Record 11 of Set 7 | margate
# Processing Record 12 of Set 7 | labuan
# Processing Record 13 of Set 7 | palana
# Processing Record 14 of Set 7 | talnakh
# Processing Record 15 of Set 7 | sorvag
# City not found. Skipping.....
# Processing Record 16 of Set 7 | kita
# Processing Record 17 of Set 7 | athabasca
# Processing Record 18 of Set 7 | mocambique
# City not found. Skipping.....
# Processing Record 19 of Set 7 | tura
# Processing Record 20 of Set 7 | marzuq
# Processing Record 21 of Set 7 | coruripe
# Processing Record 22 of Set 7 | alofi
# Processing Record 23 of Set 7 | north bend
# Processing Record 24 of Set 7 | tottori
# Processing Record 25 of Set 7 | roald
# Processing Record 26 of Set 7 | buraydah
# Processing Record 27 of Set 7 | baruun-urt
# Processing Record 28 of Set 7 | olafsvik
# Processing Record 29 of Set 7 | tigil
# Processing Record 30 of Set 7 | vao
# Processing Record 31 of Set 7 | killybegs
# Processing Record 32 of Set 7 | umm lajj
# Processing Record 33 of Set 7 | romuli
# Processing Record 34 of Set 7 | carnarvon
# Processing Record 35 of Set 7 | oranjemund
# Processing Record 36 of Set 7 | falealupo
# City not found. Skipping.....
# Processing Record 37 of Set 7 | kattivakkam
# Processing Record 38 of Set 7 | zamora
# Processing Record 39 of Set 7 | son la
# Processing Record 40 of Set 7 | wanning
# Processing Record 41 of Set 7 | albox
# Processing Record 42 of Set 7 | warqla
# City not found. Skipping.....
# Processing Record 43 of Set 7 | agirish
# Processing Record 44 of Set 7 | dingle
# Processing Record 45 of Set 7 | lewiston
# Processing Record 46 of Set 7 | sitka
# Processing Record 47 of Set 7 | sibolga
# Processing Record 48 of Set 7 | havelock
# Processing Record 49 of Set 7 | ndola
# Processing Record 50 of Set 7 | dali
# Processing Record 1 of Set 8 | gogrial
# Processing Record 2 of Set 8 | araguaina
# Processing Record 3 of Set 8 | one hundred mile house
# City not found. Skipping.....
# Processing Record 4 of Set 8 | burns lake
# Processing Record 5 of Set 8 | kavieng
# Processing Record 6 of Set 8 | the pas
# Processing Record 7 of Set 8 | calabazar de sagua
# Processing Record 8 of Set 8 | pennagaram
# Processing Record 9 of Set 8 | trimbak
# Processing Record 10 of Set 8 | luba
# Processing Record 11 of Set 8 | urdzhar
# City not found. Skipping.....
# Processing Record 12 of Set 8 | dikson
# Processing Record 13 of Set 8 | zhuzhou
# Processing Record 14 of Set 8 | tual
# Processing Record 15 of Set 8 | arlit
# Processing Record 16 of Set 8 | vostok
# Processing Record 17 of Set 8 | longyearbyen
# Processing Record 18 of Set 8 | vigia del fuerte
# Processing Record 19 of Set 8 | jalgaon
# Processing Record 20 of Set 8 | teacapan
# Processing Record 21 of Set 8 | bakchar
# Processing Record 22 of Set 8 | labuhan
# Processing Record 23 of Set 8 | palabuhanratu
# City not found. Skipping.....
# Processing Record 24 of Set 8 | yar-sale
# Processing Record 25 of Set 8 | sao joao da barra
# Processing Record 26 of Set 8 | asht
# City not found. Skipping.....
# Processing Record 27 of Set 8 | bataipora
# Processing Record 28 of Set 8 | goure
# Processing Record 29 of Set 8 | grand gaube
# Processing Record 30 of Set 8 | maceio
# Processing Record 31 of Set 8 | port hardy
# Processing Record 32 of Set 8 | innisfail
# Processing Record 33 of Set 8 | amapa
# Processing Record 34 of Set 8 | santander
# Processing Record 35 of Set 8 | barbar
# City not found. Skipping.....
# Processing Record 36 of Set 8 | siilinjarvi
# Processing Record 37 of Set 8 | belgrade
# Processing Record 38 of Set 8 | cervo
# Processing Record 39 of Set 8 | hambantota
# Processing Record 40 of Set 8 | angoche
# Processing Record 41 of Set 8 | ures
# Processing Record 42 of Set 8 | huarmey
# Processing Record 43 of Set 8 | okha
# Processing Record 44 of Set 8 | san gabriel
# Processing Record 45 of Set 8 | salym
# Processing Record 46 of Set 8 | tiarei
# Processing Record 47 of Set 8 | kamaishi
# Processing Record 48 of Set 8 | majene
# Processing Record 49 of Set 8 | shenjiamen
# Processing Record 50 of Set 8 | katha
# City not found. Skipping.....
# Processing Record 1 of Set 9 | sentyabrskiy
# City not found. Skipping.....
# Processing Record 2 of Set 9 | buzmeyin
# Processing Record 3 of Set 9 | mattru
# Processing Record 4 of Set 9 | harlingen
# Processing Record 5 of Set 9 | plouzane
# Processing Record 6 of Set 9 | ucluelet
# Processing Record 7 of Set 9 | saldanha
# Processing Record 8 of Set 9 | pochutla
# Processing Record 9 of Set 9 | isiro
# Processing Record 10 of Set 9 | martapura
# Processing Record 11 of Set 9 | iqaluit
# Processing Record 12 of Set 9 | longkou
# Processing Record 13 of Set 9 | vardo
# Processing Record 14 of Set 9 | san cristobal
# Processing Record 15 of Set 9 | buchanan
# Processing Record 16 of Set 9 | salina
# Processing Record 17 of Set 9 | staraya kulatka
# Processing Record 18 of Set 9 | marawi
# Processing Record 19 of Set 9 | mashhad
# Processing Record 20 of Set 9 | college
# Processing Record 21 of Set 9 | moron
# Processing Record 22 of Set 9 | dawlatabad
# Processing Record 23 of Set 9 | belmonte
# Processing Record 24 of Set 9 | zheleznodorozhnyy
# Processing Record 25 of Set 9 | ternate
# Processing Record 26 of Set 9 | hobyo
# Processing Record 27 of Set 9 | santa maria da vitoria
# Processing Record 28 of Set 9 | weinan
# Processing Record 29 of Set 9 | teknaf
# Processing Record 30 of Set 9 | doctor pedro p. pena
# City not found. Skipping.....
# Processing Record 31 of Set 9 | koutsouras
# Processing Record 32 of Set 9 | sawakin
# Processing Record 33 of Set 9 | tenabo
# Processing Record 34 of Set 9 | gulshat
# City not found. Skipping.....
# Processing Record 35 of Set 9 | eureka
# Processing Record 36 of Set 9 | adrar
# Processing Record 37 of Set 9 | sofiysk
# City not found. Skipping.....
# Processing Record 38 of Set 9 | dolbeau
# City not found. Skipping.....
# Processing Record 39 of Set 9 | broome
# Processing Record 40 of Set 9 | saint-ambroise
# Processing Record 41 of Set 9 | longonjo
# Processing Record 42 of Set 9 | karakendzha
# City not found. Skipping.....
# Processing Record 43 of Set 9 | mastic beach
# Processing Record 44 of Set 9 | saint george
# Processing Record 45 of Set 9 | marcona
# City not found. Skipping.....
# Processing Record 46 of Set 9 | tyrma
# Processing Record 47 of Set 9 | mys shmidta
# City not found. Skipping.....
# Processing Record 48 of Set 9 | porosozero
# Processing Record 49 of Set 9 | yuncheng
# Processing Record 50 of Set 9 | heyang
# Processing Record 1 of Set 10 | ilulissat
# Processing Record 2 of Set 10 | vanavara
# Processing Record 3 of Set 10 | broken hill
# Processing Record 4 of Set 10 | kuybysheve
# Processing Record 5 of Set 10 | umzimvubu
# City not found. Skipping.....
# Processing Record 6 of Set 10 | kjollefjord
# Processing Record 7 of Set 10 | gananoque
# Processing Record 8 of Set 10 | kawalu
# Processing Record 9 of Set 10 | port hedland
# Processing Record 10 of Set 10 | thinadhoo
# Processing Record 11 of Set 10 | severo-yeniseyskiy
# Processing Record 12 of Set 10 | lahij
# Processing Record 13 of Set 10 | bambanglipuro
# Processing Record 14 of Set 10 | ardistan
# City not found. Skipping.....
# Processing Record 15 of Set 10 | benin
# Processing Record 16 of Set 10 | okhotsk
# Processing Record 17 of Set 10 | weston
# Processing Record 18 of Set 10 | shiraz
# Processing Record 19 of Set 10 | tangermunde
# Processing Record 20 of Set 10 | bonanza
# Processing Record 21 of Set 10 | gazanjyk
# Processing Record 22 of Set 10 | eyl
# Processing Record 23 of Set 10 | samalaeulu
# City not found. Skipping.....
# Processing Record 24 of Set 10 | kanniyakumari
# Processing Record 25 of Set 10 | diamantino
# Processing Record 26 of Set 10 | bud
# Processing Record 27 of Set 10 | casambalangan
# Processing Record 28 of Set 10 | kabare
# Processing Record 29 of Set 10 | pisco
# Processing Record 30 of Set 10 | flin flon
# Processing Record 31 of Set 10 | camargo
# Processing Record 32 of Set 10 | nalut
# Processing Record 33 of Set 10 | harper
# Processing Record 34 of Set 10 | vylkove
# Processing Record 35 of Set 10 | pouebo
# Processing Record 36 of Set 10 | tateyama
# Processing Record 37 of Set 10 | praia
# Processing Record 38 of Set 10 | barcelos
# Processing Record 39 of Set 10 | melfort
# Processing Record 40 of Set 10 | kikwit
# Processing Record 41 of Set 10 | baoqing
# Processing Record 42 of Set 10 | sakakah
# Processing Record 43 of Set 10 | channel-port aux basques
# Processing Record 44 of Set 10 | altar
# Processing Record 45 of Set 10 | blois
# Processing Record 46 of Set 10 | milpitas
# Processing Record 47 of Set 10 | ayaviri
# Processing Record 48 of Set 10 | sobolevo
# Processing Record 49 of Set 10 | coshocton
# Processing Record 50 of Set 10 | werda
# Processing Record 1 of Set 11 | ijaki
# City not found. Skipping.....
# Processing Record 2 of Set 11 | candawaga
# City not found. Skipping.....
# Processing Record 3 of Set 11 | destin
# Processing Record 4 of Set 11 | morondava
# Processing Record 5 of Set 11 | norfolk
# Processing Record 6 of Set 11 | wanxian
# Processing Record 7 of Set 11 | norman
# Processing Record 8 of Set 11 | kudahuvadhoo
# Processing Record 9 of Set 11 | rancho palos verdes
# Processing Record 10 of Set 11 | itoman
# Processing Record 11 of Set 11 | sorland
# Processing Record 12 of Set 11 | westport
# Processing Record 13 of Set 11 | karratha
# Processing Record 14 of Set 11 | dunedin
# Processing Record 15 of Set 11 | marion
# Processing Record 16 of Set 11 | waipawa
# Processing Record 17 of Set 11 | kant
# Processing Record 18 of Set 11 | mentok
# City not found. Skipping.....
# Processing Record 19 of Set 11 | belyy yar
# Processing Record 20 of Set 11 | chornoliztsi
# Processing Record 21 of Set 11 | rabo de peixe
# Processing Record 22 of Set 11 | mayumba
# Processing Record 23 of Set 11 | san quintin
# Processing Record 24 of Set 11 | matay
# Processing Record 25 of Set 11 | udachnyy
# Processing Record 26 of Set 11 | korla
# Processing Record 27 of Set 11 | cibitoke
# Processing Record 28 of Set 11 | bollnas
# Processing Record 29 of Set 11 | walvis bay
# Processing Record 30 of Set 11 | ponta delgada
# Processing Record 31 of Set 11 | kyrylivka
# Processing Record 32 of Set 11 | saint-denis
# Processing Record 33 of Set 11 | tarudant
# City not found. Skipping.....
# Processing Record 34 of Set 11 | denpasar
# Processing Record 35 of Set 11 | goderich
# Processing Record 36 of Set 11 | taoudenni
# Processing Record 37 of Set 11 | hualmay
# Processing Record 38 of Set 11 | richards bay
# Processing Record 39 of Set 11 | hit
# Processing Record 40 of Set 11 | statesboro
# Processing Record 41 of Set 11 | duldurga
# Processing Record 42 of Set 11 | madang
# Processing Record 43 of Set 11 | puerto carreno
# Processing Record 44 of Set 11 | ganzhou
# Processing Record 45 of Set 11 | beloha
# Processing Record 46 of Set 11 | pilar
# Processing Record 47 of Set 11 | alekseyevsk
# Processing Record 48 of Set 11 | aksu
# Processing Record 49 of Set 11 | namibe
# Processing Record 50 of Set 11 | huntington
# Processing Record 1 of Set 12 | cockburn town
# Processing Record 2 of Set 12 | constitucion
# Processing Record 3 of Set 12 | blagoveshchensk
# Processing Record 4 of Set 12 | blagoyevo
# Processing Record 5 of Set 12 | tabialan
# City not found. Skipping.....
# Processing Record 6 of Set 12 | jabiru
# City not found. Skipping.....
# Processing Record 7 of Set 12 | gujan-mestras
# Processing Record 8 of Set 12 | taganak
# Processing Record 9 of Set 12 | grootfontein
# Processing Record 10 of Set 12 | borama
# City not found. Skipping.....
# Processing Record 11 of Set 12 | shasta lake
# Processing Record 12 of Set 12 | shakawe
# Processing Record 13 of Set 12 | necochea
# Processing Record 14 of Set 12 | ust-kuyga
# Processing Record 15 of Set 12 | muroto
# Processing Record 16 of Set 12 | qaqortoq
# Processing Record 17 of Set 12 | kavarskas
# Processing Record 18 of Set 12 | monreal
# Processing Record 19 of Set 12 | komsomolskiy
# Processing Record 20 of Set 12 | haibowan
# City not found. Skipping.....
# Processing Record 21 of Set 12 | reconquista
# Processing Record 22 of Set 12 | gao
# Processing Record 23 of Set 12 | deputatskiy
# Processing Record 24 of Set 12 | kirkland lake
# Processing Record 25 of Set 12 | toftir
# City not found. Skipping.....
# Processing Record 26 of Set 12 | port-gentil
# Processing Record 27 of Set 12 | grindavik
# Processing Record 28 of Set 12 | ilo
# Processing Record 29 of Set 12 | ust-kamchatsk
# City not found. Skipping.....
# Processing Record 30 of Set 12 | lompoc
# Processing Record 31 of Set 12 | urgut
# Processing Record 32 of Set 12 | sola
# Processing Record 33 of Set 12 | grande prairie
# Processing Record 34 of Set 12 | garleni
# Processing Record 35 of Set 12 | mizan teferi
# Processing Record 36 of Set 12 | north battleford
# Processing Record 37 of Set 12 | aykhal
# Processing Record 38 of Set 12 | ulcinj
# Processing Record 39 of Set 12 | pacific grove
# Processing Record 40 of Set 12 | bonga
# Processing Record 41 of Set 12 | floro
# Processing Record 42 of Set 12 | arman
# Processing Record 43 of Set 12 | mathbaria
# Processing Record 44 of Set 12 | ubinskoye
# Processing Record 45 of Set 12 | mizdah
# Processing Record 46 of Set 12 | kamenskoye
# City not found. Skipping.....
# Processing Record 47 of Set 12 | virden
# Processing Record 48 of Set 12 | smithers
# Processing Record 49 of Set 12 | shingu
# Processing Record 50 of Set 12 | matagami
# Processing Record 1 of Set 13 | rungata
# City not found. Skipping.....
# Processing Record 2 of Set 13 | pindobacu
# Processing Record 3 of Set 13 | los llanos de aridane
# Processing Record 4 of Set 13 | coolum beach
# Processing Record 5 of Set 13 | henties bay
# Processing Record 6 of Set 13 | tres arroyos
# Processing Record 7 of Set 13 | beidao
# Processing Record 8 of Set 13 | hovd
# Processing Record 9 of Set 13 | ferrol
# Processing Record 10 of Set 13 | ullapool
# Processing Record 11 of Set 13 | kibray
# Processing Record 12 of Set 13 | ikom
# Processing Record 13 of Set 13 | gambo
# Processing Record 14 of Set 13 | camacha
# Processing Record 15 of Set 13 | aromashevo
# Processing Record 16 of Set 13 | charta
# Processing Record 17 of Set 13 | caceres
# Processing Record 18 of Set 13 | sanandaj
# Processing Record 19 of Set 13 | gat
# Processing Record 20 of Set 13 | bandarbeyla
# Processing Record 21 of Set 13 | abu dhabi
# Processing Record 22 of Set 13 | dongli
# Processing Record 23 of Set 13 | dicabisagan
# Processing Record 24 of Set 13 | mazyr
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Nantucket  41.2835  -70.0995     44.96        55          64
# 1         Rikitea -23.1203 -134.9692     76.15        74          98
# 2     Yellowknife  62.4560 -114.3525    -14.58        83          20
# 3           Erice  38.0370   12.5865     44.44        87          40
# 4  Port Elizabeth -33.9180   25.5701     66.09       100           0
# 5    Punta Arenas -53.1500  -70.9167     55.51        44          20
# 6   Mar Del Plata -38.0023  -57.5575     66.22        82          20
# 7           Vaini -21.2000 -175.2000     80.76        83          75
# 8         Fortuna  40.5982 -124.1573     55.33        94          90
# 9            Asfi  32.2994   -9.2372     59.11        81           0
#
#    Wind Speed Country                date
# 0        2.33      US  2021-1205 20:41:19
# 1        8.23      PF  2021-1205 20:41:20
# 2        4.61      CA  2021-1205 20:41:20
# 3        4.61      IT  2021-1205 20:41:20
# 4        3.44      ZA  2021-1205 20:41:21
# 5       24.16      CL  2021-1205 20:40:16
# 6       11.99      AR  2021-1205 20:36:38
# 7       10.36      TO  2021-1205 20:41:21
# 8        8.05      US  2021-1205 20:41:21
# 9       21.56      MA  2021-1205 20:41:22

# %%
new_column_order = ['City', 'Country', 'date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df.head(15)
# Out:
#               City Country                date      Lat       Lng  Max Temp  \
# 0        Nantucket      US  2021-1205 20:41:19  41.2835  -70.0995     44.96
# 1          Rikitea      PF  2021-1205 20:41:20 -23.1203 -134.9692     76.15
# 2      Yellowknife      CA  2021-1205 20:41:20  62.4560 -114.3525    -14.58
# 3            Erice      IT  2021-1205 20:41:20  38.0370   12.5865     44.44
# 4   Port Elizabeth      ZA  2021-1205 20:41:21 -33.9180   25.5701     66.09
# 5     Punta Arenas      CL  2021-1205 20:40:16 -53.1500  -70.9167     55.51
# 6    Mar Del Plata      AR  2021-1205 20:36:38 -38.0023  -57.5575     66.22
# 7            Vaini      TO  2021-1205 20:41:21 -21.2000 -175.2000     80.76
# 8          Fortuna      US  2021-1205 20:41:21  40.5982 -124.1573     55.33
# 9             Asfi      MA  2021-1205 20:41:22  32.2994   -9.2372     59.11
# 10       Okakarara      NA  2021-1205 20:41:22 -20.5833   17.4333     70.09
# 11          Luanda      AO  2021-1205 20:41:22  -8.8368   13.2343     80.60
# 12         Atambua      ID  2021-1205 20:41:23  -9.1061  124.8925     74.23
# 13           Jatai      BR  2021-1205 20:41:23 -17.8814  -51.7144     79.84
# 14      Folkestone      GB  2021-1205 20:41:23  51.0833    1.1833     42.78
#
#     Humidity  Cloudiness  Wind Speed
# 0         55          64        2.33
# 1         74          98        8.23
# 2         83          20        4.61
# 3         87          40        4.61
# 4        100           0        3.44
# 5         44          20       24.16
# 6         82          20       11.99
# 7         83          75       10.36
# 8         94          90        8.05
# 9         81           0       21.56
# 10        11           0        9.22
# 11        83          40       11.50
# 12        90         100        1.43
# 13        65          70        1.90
# 14        93          82        8.01

# %%
import os
cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in '/Users/armandolatigo/Desktop/Analysis Projects/World_Weather_Analysis': ['.DS_Store', 'config.py', '__pycache__', 'README.md', 'random_numbers.ipynb', '.gitignore', 'weather_data', 'WeatherPy.ipynb', '.ipynb_checkpoints', '.git', 'API_Practice.ipynb']

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting
lats = city_data_df['Lat']
max_temps = city_data_df['Max Temp']
humidity = city_data_df['Humidity']
cloudiness = city_data_df['Cloudiness']
wind_speed = city_data_df['Wind Speed']

# %%
# Import the time module
import time

# Build the scatetr plot for latitude vs max temperature
plt.scatter(lats, max_temps,
            edgecolor = 'k',
            linewidths = 1,
            marker = 'o',
            alpha = 0.8,
            label = 'cities')

#Incorporate the graph properties.
plt.title(f'City Latitude vs Max Temperature ' + time.strftime("%x"))
plt.ylabel("Max Temperature")
plt.xlabel("Latitude")
plt.grid(True)

#Save the figure
plt.savefig("weather_data/Fig1.png")

#Show Figure
plt.show()

# %%
# Build the scatetr plot for latitude vs humidity
plt.scatter(lats, humidity,
            edgecolor = 'k',
            linewidths = 1,
            marker = 'o',
            alpha = 0.8,
            label = 'cities')

#Incorporate the graph properties.
plt.title(f'City Latitude vs Humidity ' + time.strftime("%x"))
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

#Save the figure
plt.savefig("weather_data/Fig2.png")

#Show Figure
plt.show()

# %%
# Build the scatetr plot for latitude vs max temperature
plt.scatter(lats, cloudiness,
            edgecolor = 'k',
            linewidths = 1,
            marker = 'o',
            alpha = 0.8,
            label = 'cities')

#Incorporate the graph properties.
plt.title(f'City Latitude vs Cloudiness ' + time.strftime("%x"))
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

#Save the figure
plt.savefig("weather_data/Fig3.png")

#Show Figure
plt.show()

# %%
#Build the scatter plots for latitude vs. wind speed
plt.scatter(lats,wind_speed,
            edgecolor = 'k',
            linewidths = 1,
            marker = 'o',
            alpha = 0.8,
            label = 'cities')

#Incorporate the graph properties
plt.title('City Latitude vs Wind Speed ' + time.strftime('%x'))
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('weather_data/Fig4.png')
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
from scipy.stats import linregress

# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
     # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                       Jatai
# Country                       BR
# date          2021-1205 20:41:23
# Lat                     -17.8814
# Lng                     -51.7144
# Max Temp                   79.84
# Humidity                      65
# Cloudiness                    70
# Wind Speed                   1.9
# Name: 13, dtype: object

# %%
city_data_df['Lat'] >= 0
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 560     True
# 561     True
# 562     True
# 563     True
# 564     True
# Name: Lat, Length: 565, dtype: bool

# %%
city_data_df.loc[(city_data_df['Lat'] >= 0)].head()
# Out:
#           City Country                date      Lat       Lng  Max Temp  \
# 0    Nantucket      US  2021-1205 20:41:19  41.2835  -70.0995     44.96
# 2  Yellowknife      CA  2021-1205 20:41:20  62.4560 -114.3525    -14.58
# 3        Erice      IT  2021-1205 20:41:20  38.0370   12.5865     44.44
# 8      Fortuna      US  2021-1205 20:41:21  40.5982 -124.1573     55.33
# 9         Asfi      MA  2021-1205 20:41:22  32.2994   -9.2372     59.11
#
#    Humidity  Cloudiness  Wind Speed
# 0        55          64        2.33
# 2        83          20        4.61
# 3        87          40        4.61
# 8        94          90        8.05
# 9        81           0       21.56

# %%
northern_hemi_df = city_data_df.loc[(city_data_df['Lat'] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df['Lat'] < 0)]

# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor Maximum Temperature',
                       'Max Temp',(3,-45))

# %%
northern_hemi_df = city_data_df.loc[(city_data_df['Lat'] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df['Lat'] < 0)]

# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor Maximum Temperature',
                       'Max Temp',(-55,37))

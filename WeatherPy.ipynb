# %%
#pip install citipy

# %%
#import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=1500)
lngs = np.random.uniform(low=-180.000,high=180.000,size=1500)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy
 
# Create a list for holding the cities

cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 608

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
print("Hello")
# Out:
# Hello

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

#Starting URL for Weather Map API Call."
#manually enter API ...&appid= x
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid="+weather_api_key
# Create an endpoint URL for a city
city_url = url + "&q=" + "Boston"

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval   ")
print("----------------------------")

# Create counters
record_count = 1 
set_count = 1

#Loop through all the cities in our list
#for i in range(len(cities)):
    
    #Group cities in sets of 50 for logging purposes
    #if (i % 50 == 0 and i >= 50):
     #   set_count += 1
      #  record_count = 1
        #time.sleep(60)
    
    #Create endpoint URL with each city
   # city_url = url + "&q=" + cities[i]


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
#Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
           
        
        #Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
                                   
        #Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "date": city_date})
        
# If an error occurs, skip city.
    except:
        print("City not found. Skipping.....")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | cockburn town
# Processing Record 4 of Set 1 | wasilla
# Processing Record 5 of Set 1 | broome
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping.....
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | lasa
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | villazon
# Processing Record 11 of Set 1 | san andres
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | dreznica
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping.....
# Processing Record 16 of Set 1 | saint anthony
# Processing Record 17 of Set 1 | jumla
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | zhaotong
# Processing Record 21 of Set 1 | mys shmidta
# City not found. Skipping.....
# Processing Record 22 of Set 1 | bathsheba
# Processing Record 23 of Set 1 | ulladulla
# Processing Record 24 of Set 1 | kruisfontein
# Processing Record 25 of Set 1 | wonthaggi
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping.....
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | turan
# Processing Record 32 of Set 1 | sorong
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | belmonte
# Processing Record 35 of Set 1 | santa cruz
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping.....
# Processing Record 37 of Set 1 | maningrida
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | tsihombe
# City not found. Skipping.....
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | skender vakuf
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | provideniya
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | dawei
# Processing Record 48 of Set 1 | shimoda
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | tual
# Processing Record 1 of Set 2 | bitlis
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | cherskiy
# Processing Record 5 of Set 2 | sao filipe
# Processing Record 6 of Set 2 | isangel
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | kudahuvadhoo
# Processing Record 10 of Set 2 | bengkulu
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | konstantinovo
# Processing Record 13 of Set 2 | dzaoudzi
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | lac du bonnet
# Processing Record 16 of Set 2 | longyearbyen
# Processing Record 17 of Set 2 | barra do corda
# Processing Record 18 of Set 2 | kropotkin
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | cabo san lucas
# Processing Record 22 of Set 2 | barcelona
# Processing Record 23 of Set 2 | namatanai
# Processing Record 24 of Set 2 | luoyang
# Processing Record 25 of Set 2 | iberia
# Processing Record 26 of Set 2 | aklavik
# Processing Record 27 of Set 2 | airai
# Processing Record 28 of Set 2 | banes
# Processing Record 29 of Set 2 | derzhavinsk
# Processing Record 30 of Set 2 | elizabeth city
# Processing Record 31 of Set 2 | victoria
# Processing Record 32 of Set 2 | mullaitivu
# City not found. Skipping.....
# Processing Record 33 of Set 2 | temiscaming
# Processing Record 34 of Set 2 | mitsamiouli
# Processing Record 35 of Set 2 | riyadh
# Processing Record 36 of Set 2 | panama city
# Processing Record 37 of Set 2 | brae
# Processing Record 38 of Set 2 | dingle
# Processing Record 39 of Set 2 | bilibino
# Processing Record 40 of Set 2 | yumen
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | talcahuano
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | leningradskiy
# Processing Record 45 of Set 2 | usinsk
# Processing Record 46 of Set 2 | margate
# Processing Record 47 of Set 2 | auki
# Processing Record 48 of Set 2 | opuwo
# Processing Record 49 of Set 2 | hambantota
# Processing Record 50 of Set 2 | ancud
# Processing Record 1 of Set 3 | terrace
# Processing Record 2 of Set 3 | pokhara
# Processing Record 3 of Set 3 | mahebourg
# Processing Record 4 of Set 3 | yanam
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | yanan
# City not found. Skipping.....
# Processing Record 7 of Set 3 | krasnoarmeysk
# Processing Record 8 of Set 3 | karratha
# Processing Record 9 of Set 3 | ahipara
# Processing Record 10 of Set 3 | klaksvik
# Processing Record 11 of Set 3 | tongren
# Processing Record 12 of Set 3 | portland
# Processing Record 13 of Set 3 | deputatskiy
# Processing Record 14 of Set 3 | lysogorskaya
# Processing Record 15 of Set 3 | taolanaro
# City not found. Skipping.....
# Processing Record 16 of Set 3 | tazmalt
# Processing Record 17 of Set 3 | shemgang
# Processing Record 18 of Set 3 | remanso
# Processing Record 19 of Set 3 | nyurba
# Processing Record 20 of Set 3 | copiapo
# Processing Record 21 of Set 3 | chokurdakh
# Processing Record 22 of Set 3 | clarence town
# Processing Record 23 of Set 3 | haines junction
# Processing Record 24 of Set 3 | waddan
# Processing Record 25 of Set 3 | tumannyy
# City not found. Skipping.....
# Processing Record 26 of Set 3 | clyde river
# Processing Record 27 of Set 3 | fairbanks
# Processing Record 28 of Set 3 | kavieng
# Processing Record 29 of Set 3 | aquiraz
# Processing Record 30 of Set 3 | qaanaaq
# Processing Record 31 of Set 3 | mogzon
# Processing Record 32 of Set 3 | hualmay
# Processing Record 33 of Set 3 | huilong
# Processing Record 34 of Set 3 | kargasok
# Processing Record 35 of Set 3 | versalles
# Processing Record 36 of Set 3 | pomezia
# Processing Record 37 of Set 3 | cayenne
# Processing Record 38 of Set 3 | camocim
# Processing Record 39 of Set 3 | kracheh
# City not found. Skipping.....
# Processing Record 40 of Set 3 | avera
# Processing Record 41 of Set 3 | fairview
# Processing Record 42 of Set 3 | faanui
# Processing Record 43 of Set 3 | agadez
# Processing Record 44 of Set 3 | caravelas
# Processing Record 45 of Set 3 | riviere-au-renard
# Processing Record 46 of Set 3 | wajima
# Processing Record 47 of Set 3 | attawapiskat
# City not found. Skipping.....
# Processing Record 48 of Set 3 | anzio
# Processing Record 49 of Set 3 | kedrovyy
# Processing Record 50 of Set 3 | nome
# Processing Record 1 of Set 4 | suleja
# Processing Record 2 of Set 4 | lata
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | sarangani
# Processing Record 5 of Set 4 | esperance
# Processing Record 6 of Set 4 | pisco
# Processing Record 7 of Set 4 | marzuq
# Processing Record 8 of Set 4 | mount isa
# Processing Record 9 of Set 4 | banda aceh
# Processing Record 10 of Set 4 | bayir
# Processing Record 11 of Set 4 | novoanninskiy
# Processing Record 12 of Set 4 | san patricio
# Processing Record 13 of Set 4 | sangar
# Processing Record 14 of Set 4 | kaitangata
# Processing Record 15 of Set 4 | chuy
# Processing Record 16 of Set 4 | noyabrsk
# Processing Record 17 of Set 4 | ponta do sol
# Processing Record 18 of Set 4 | zhigansk
# Processing Record 19 of Set 4 | san cristobal
# Processing Record 20 of Set 4 | rio gallegos
# Processing Record 21 of Set 4 | scarborough
# Processing Record 22 of Set 4 | teguldet
# Processing Record 23 of Set 4 | prince rupert
# Processing Record 24 of Set 4 | grand river south east
# City not found. Skipping.....
# Processing Record 25 of Set 4 | nioro
# Processing Record 26 of Set 4 | hereford
# Processing Record 27 of Set 4 | yellowknife
# Processing Record 28 of Set 4 | nalut
# Processing Record 29 of Set 4 | ferkessedougou
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | sayyan
# Processing Record 32 of Set 4 | port alfred
# Processing Record 33 of Set 4 | balykshi
# Processing Record 34 of Set 4 | norman wells
# Processing Record 35 of Set 4 | newcastle
# Processing Record 36 of Set 4 | nogent-le-rotrou
# Processing Record 37 of Set 4 | luderitz
# Processing Record 38 of Set 4 | tarudant
# City not found. Skipping.....
# Processing Record 39 of Set 4 | dikson
# Processing Record 40 of Set 4 | barrow
# Processing Record 41 of Set 4 | torbay
# Processing Record 42 of Set 4 | raudeberg
# Processing Record 43 of Set 4 | waipawa
# Processing Record 44 of Set 4 | oussouye
# Processing Record 45 of Set 4 | thompson
# Processing Record 46 of Set 4 | jaisinghnagar
# Processing Record 47 of Set 4 | fengrun
# Processing Record 48 of Set 4 | mayo
# Processing Record 49 of Set 4 | arraial do cabo
# Processing Record 50 of Set 4 | saint-francois
# Processing Record 1 of Set 5 | new norfolk
# Processing Record 2 of Set 5 | vanimo
# Processing Record 3 of Set 5 | lolua
# City not found. Skipping.....
# Processing Record 4 of Set 5 | savonlinna
# Processing Record 5 of Set 5 | qinhuangdao
# Processing Record 6 of Set 5 | diamantino
# Processing Record 7 of Set 5 | koupela
# Processing Record 8 of Set 5 | gondanglegi
# Processing Record 9 of Set 5 | acarau
# Processing Record 10 of Set 5 | alyangula
# Processing Record 11 of Set 5 | tessalit
# Processing Record 12 of Set 5 | brownfield
# Processing Record 13 of Set 5 | sitka
# Processing Record 14 of Set 5 | kavaratti
# Processing Record 15 of Set 5 | codrington
# Processing Record 16 of Set 5 | vila velha
# Processing Record 17 of Set 5 | henties bay
# Processing Record 18 of Set 5 | orange cove
# Processing Record 19 of Set 5 | castro
# Processing Record 20 of Set 5 | santa fe
# Processing Record 21 of Set 5 | lompoc
# Processing Record 22 of Set 5 | sao joao da barra
# Processing Record 23 of Set 5 | zadar
# Processing Record 24 of Set 5 | aflu
# City not found. Skipping.....
# Processing Record 25 of Set 5 | casper
# Processing Record 26 of Set 5 | cidreira
# Processing Record 27 of Set 5 | guanare
# Processing Record 28 of Set 5 | lebu
# Processing Record 29 of Set 5 | pacific grove
# Processing Record 30 of Set 5 | chake chake
# Processing Record 31 of Set 5 | goderich
# Processing Record 32 of Set 5 | nizhniy kuranakh
# Processing Record 33 of Set 5 | sokoni
# Processing Record 34 of Set 5 | touros
# Processing Record 35 of Set 5 | pangnirtung
# Processing Record 36 of Set 5 | andenes
# Processing Record 37 of Set 5 | chaa-khol
# City not found. Skipping.....
# Processing Record 38 of Set 5 | likhoslavl
# Processing Record 39 of Set 5 | palmer
# Processing Record 40 of Set 5 | san ramon
# Processing Record 41 of Set 5 | nikolskoye
# Processing Record 42 of Set 5 | lavrentiya
# Processing Record 43 of Set 5 | talara
# Processing Record 44 of Set 5 | port lincoln
# Processing Record 45 of Set 5 | san jeronimo
# Processing Record 46 of Set 5 | salalah
# Processing Record 47 of Set 5 | tasiilaq
# Processing Record 48 of Set 5 | parambu
# Processing Record 49 of Set 5 | morehead
# Processing Record 50 of Set 5 | saskylakh
# Processing Record 1 of Set 6 | zambezi
# Processing Record 2 of Set 6 | kijang
# Processing Record 3 of Set 6 | ulaanbaatar
# Processing Record 4 of Set 6 | lamu
# Processing Record 5 of Set 6 | chara
# Processing Record 6 of Set 6 | velyka lepetykha
# Processing Record 7 of Set 6 | makakilo city
# Processing Record 8 of Set 6 | popondetta
# Processing Record 9 of Set 6 | santa cruz del sur
# Processing Record 10 of Set 6 | manicore
# Processing Record 11 of Set 6 | bukama
# Processing Record 12 of Set 6 | boyolangu
# Processing Record 13 of Set 6 | rawson
# Processing Record 14 of Set 6 | biak
# Processing Record 15 of Set 6 | bubaque
# Processing Record 16 of Set 6 | namibe
# Processing Record 17 of Set 6 | skjervoy
# Processing Record 18 of Set 6 | linchuan
# City not found. Skipping.....
# Processing Record 19 of Set 6 | claremore
# Processing Record 20 of Set 6 | tabou
# Processing Record 21 of Set 6 | nizhneyansk
# City not found. Skipping.....
# Processing Record 22 of Set 6 | kahului
# Processing Record 23 of Set 6 | port hardy
# Processing Record 24 of Set 6 | vila
# Processing Record 25 of Set 6 | warqla
# City not found. Skipping.....
# Processing Record 26 of Set 6 | portage
# Processing Record 27 of Set 6 | itarema
# Processing Record 28 of Set 6 | honningsvag
# Processing Record 29 of Set 6 | chernyakhovsk
# Processing Record 30 of Set 6 | luga
# Processing Record 31 of Set 6 | pak phanang
# Processing Record 32 of Set 6 | chulym
# Processing Record 33 of Set 6 | hengshui
# Processing Record 34 of Set 6 | moree
# Processing Record 35 of Set 6 | peniche
# Processing Record 36 of Set 6 | puri
# Processing Record 37 of Set 6 | richards bay
# Processing Record 38 of Set 6 | uruzgan
# Processing Record 39 of Set 6 | arlit
# Processing Record 40 of Set 6 | ciudad bolivar
# Processing Record 41 of Set 6 | sabha
# Processing Record 42 of Set 6 | alofi
# Processing Record 43 of Set 6 | magrath
# Processing Record 44 of Set 6 | ambilobe
# Processing Record 45 of Set 6 | puerto madryn
# Processing Record 46 of Set 6 | jefferson city
# Processing Record 47 of Set 6 | resistencia
# Processing Record 48 of Set 6 | sharjah
# Processing Record 49 of Set 6 | severo-kurilsk
# Processing Record 50 of Set 6 | nanortalik
# Processing Record 1 of Set 7 | hervey bay
# Processing Record 2 of Set 7 | sao gabriel da cachoeira
# Processing Record 3 of Set 7 | skibbereen
# Processing Record 4 of Set 7 | berlevag
# Processing Record 5 of Set 7 | labuhan
# Processing Record 6 of Set 7 | chivay
# Processing Record 7 of Set 7 | asfi
# Processing Record 8 of Set 7 | znamenskoye
# Processing Record 9 of Set 7 | ugoofaaru
# Processing Record 10 of Set 7 | faribault
# Processing Record 11 of Set 7 | xinzhou
# Processing Record 12 of Set 7 | bontang
# Processing Record 13 of Set 7 | bambui
# Processing Record 14 of Set 7 | eskisehir
# Processing Record 15 of Set 7 | narsaq
# Processing Record 16 of Set 7 | anda
# Processing Record 17 of Set 7 | borogontsy
# Processing Record 18 of Set 7 | beroroha
# Processing Record 19 of Set 7 | broken hill
# Processing Record 20 of Set 7 | ekhabi
# Processing Record 21 of Set 7 | ozgon
# City not found. Skipping.....
# Processing Record 22 of Set 7 | durango
# Processing Record 23 of Set 7 | pimenteiras
# Processing Record 24 of Set 7 | coos bay
# Processing Record 25 of Set 7 | souillac
# Processing Record 26 of Set 7 | concordia
# Processing Record 27 of Set 7 | palabuhanratu
# City not found. Skipping.....
# Processing Record 28 of Set 7 | mukhen
# Processing Record 29 of Set 7 | leshukonskoye
# Processing Record 30 of Set 7 | khatanga
# Processing Record 31 of Set 7 | forbes
# Processing Record 32 of Set 7 | gladstone
# Processing Record 33 of Set 7 | fez
# Processing Record 34 of Set 7 | haapiti
# Processing Record 35 of Set 7 | champasak
# Processing Record 36 of Set 7 | la uribe
# City not found. Skipping.....
# Processing Record 37 of Set 7 | ambon
# Processing Record 38 of Set 7 | san rafael
# Processing Record 39 of Set 7 | sambava
# Processing Record 40 of Set 7 | saint george
# Processing Record 41 of Set 7 | geraldton
# Processing Record 42 of Set 7 | san julian
# Processing Record 43 of Set 7 | katsuura
# Processing Record 44 of Set 7 | blagoveshchensk
# Processing Record 45 of Set 7 | tidore
# City not found. Skipping.....
# Processing Record 46 of Set 7 | tunduru
# City not found. Skipping.....
# Processing Record 47 of Set 7 | borba
# Processing Record 48 of Set 7 | luanda
# Processing Record 49 of Set 7 | vanavara
# Processing Record 50 of Set 7 | zhuhai
# Processing Record 1 of Set 8 | benjamin constant
# Processing Record 2 of Set 8 | bereznik
# Processing Record 3 of Set 8 | malakal
# Processing Record 4 of Set 8 | pacifica
# Processing Record 5 of Set 8 | adrar
# Processing Record 6 of Set 8 | pringsewu
# Processing Record 7 of Set 8 | ovria
# Processing Record 8 of Set 8 | ati
# Processing Record 9 of Set 8 | flinders
# Processing Record 10 of Set 8 | jalu
# Processing Record 11 of Set 8 | okhotsk
# Processing Record 12 of Set 8 | pilar
# Processing Record 13 of Set 8 | shache
# Processing Record 14 of Set 8 | barawe
# City not found. Skipping.....
# Processing Record 15 of Set 8 | atar
# Processing Record 16 of Set 8 | barroualie
# City not found. Skipping.....
# Processing Record 17 of Set 8 | verkhnevilyuysk
# Processing Record 18 of Set 8 | panacan
# Processing Record 19 of Set 8 | pangai
# Processing Record 20 of Set 8 | maniitsoq
# Processing Record 21 of Set 8 | abu jubayhah
# City not found. Skipping.....
# Processing Record 22 of Set 8 | nioki
# Processing Record 23 of Set 8 | lufkin
# Processing Record 24 of Set 8 | meshchovsk
# Processing Record 25 of Set 8 | umzimvubu
# City not found. Skipping.....
# Processing Record 26 of Set 8 | tilichiki
# Processing Record 27 of Set 8 | oranjemund
# Processing Record 28 of Set 8 | port macquarie
# Processing Record 29 of Set 8 | boksitogorsk
# Processing Record 30 of Set 8 | neiafu
# Processing Record 31 of Set 8 | tayu
# Processing Record 32 of Set 8 | kupino
# Processing Record 33 of Set 8 | artyk
# City not found. Skipping.....
# Processing Record 34 of Set 8 | rudnyy
# Processing Record 35 of Set 8 | carutapera
# Processing Record 36 of Set 8 | voznesenye
# Processing Record 37 of Set 8 | sakhon nakhon
# Processing Record 38 of Set 8 | gurskoye
# City not found. Skipping.....
# Processing Record 39 of Set 8 | ust-tsilma
# Processing Record 40 of Set 8 | boundiali
# Processing Record 41 of Set 8 | guerrero negro
# Processing Record 42 of Set 8 | kerema
# Processing Record 43 of Set 8 | galle
# Processing Record 44 of Set 8 | yershichi
# Processing Record 45 of Set 8 | mikkeli
# Processing Record 46 of Set 8 | tungkang
# City not found. Skipping.....
# Processing Record 47 of Set 8 | kangaatsiaq
# Processing Record 48 of Set 8 | brewster
# Processing Record 49 of Set 8 | vila praia de ancora
# Processing Record 50 of Set 8 | mastic beach
# Processing Record 1 of Set 9 | shrewsbury
# Processing Record 2 of Set 9 | yarmouth
# Processing Record 3 of Set 9 | warman
# Processing Record 4 of Set 9 | mayor pablo lagerenza
# Processing Record 5 of Set 9 | digha
# Processing Record 6 of Set 9 | jeremie
# Processing Record 7 of Set 9 | ostersund
# Processing Record 8 of Set 9 | eyl
# Processing Record 9 of Set 9 | mehamn
# Processing Record 10 of Set 9 | yantal
# Processing Record 11 of Set 9 | biltine
# Processing Record 12 of Set 9 | pa sang
# Processing Record 13 of Set 9 | gorno-chuyskiy
# City not found. Skipping.....
# Processing Record 14 of Set 9 | koundara
# Processing Record 15 of Set 9 | flin flon
# Processing Record 16 of Set 9 | setubal
# Processing Record 17 of Set 9 | inhambane
# Processing Record 18 of Set 9 | makamba
# Processing Record 19 of Set 9 | oranjestad
# Processing Record 20 of Set 9 | sur
# Processing Record 21 of Set 9 | acapulco
# Processing Record 22 of Set 9 | tadine
# Processing Record 23 of Set 9 | rungata
# City not found. Skipping.....
# Processing Record 24 of Set 9 | maku
# Processing Record 25 of Set 9 | coihaique
# Processing Record 26 of Set 9 | kirkwall
# Processing Record 27 of Set 9 | ostrovnoy
# Processing Record 28 of Set 9 | ketchikan
# Processing Record 29 of Set 9 | cochrane
# Processing Record 30 of Set 9 | yar-sale
# Processing Record 31 of Set 9 | alice springs
# Processing Record 32 of Set 9 | alekseyevskoye
# Processing Record 33 of Set 9 | gerash
# Processing Record 34 of Set 9 | concepcion del uruguay
# Processing Record 35 of Set 9 | kununurra
# Processing Record 36 of Set 9 | koungheul
# Processing Record 37 of Set 9 | nouakchott
# Processing Record 38 of Set 9 | marsh harbour
# Processing Record 39 of Set 9 | wulanhaote
# City not found. Skipping.....
# Processing Record 40 of Set 9 | tuatapere
# Processing Record 41 of Set 9 | saleaula
# City not found. Skipping.....
# Processing Record 42 of Set 9 | jiwani
# Processing Record 43 of Set 9 | muisne
# Processing Record 44 of Set 9 | gushikawa
# Processing Record 45 of Set 9 | monrovia
# Processing Record 46 of Set 9 | diego de almagro
# Processing Record 47 of Set 9 | badulla
# Processing Record 48 of Set 9 | turukhansk
# Processing Record 49 of Set 9 | vasteras
# Processing Record 50 of Set 9 | kupang
# Processing Record 1 of Set 10 | lamin
# Processing Record 2 of Set 10 | praya
# Processing Record 3 of Set 10 | kamien pomorski
# Processing Record 4 of Set 10 | yaviza
# Processing Record 5 of Set 10 | varangaon
# Processing Record 6 of Set 10 | coahuayana
# Processing Record 7 of Set 10 | bandarbeyla
# Processing Record 8 of Set 10 | puerto escondido
# Processing Record 9 of Set 10 | batemans bay
# Processing Record 10 of Set 10 | lerwick
# Processing Record 11 of Set 10 | hasaki
# Processing Record 12 of Set 10 | hay river
# Processing Record 13 of Set 10 | westport
# Processing Record 14 of Set 10 | dve mogili
# Processing Record 15 of Set 10 | jieshi
# Processing Record 16 of Set 10 | coquimbo
# Processing Record 17 of Set 10 | dakar
# Processing Record 18 of Set 10 | koumac
# Processing Record 19 of Set 10 | nelson bay
# Processing Record 20 of Set 10 | gat
# Processing Record 21 of Set 10 | marienburg
# Processing Record 22 of Set 10 | jabinyanah
# Processing Record 23 of Set 10 | yayva
# Processing Record 24 of Set 10 | iqaluit
# Processing Record 25 of Set 10 | kizukuri
# Processing Record 26 of Set 10 | kampene
# Processing Record 27 of Set 10 | byron bay
# Processing Record 28 of Set 10 | taiyuan
# Processing Record 29 of Set 10 | ravar
# Processing Record 30 of Set 10 | corner brook
# Processing Record 31 of Set 10 | grindavik
# Processing Record 32 of Set 10 | baruun-urt
# Processing Record 33 of Set 10 | inderborskiy
# City not found. Skipping.....
# Processing Record 34 of Set 10 | tabuk
# Processing Record 35 of Set 10 | fort nelson
# Processing Record 36 of Set 10 | gizo
# Processing Record 37 of Set 10 | zanjan
# Processing Record 38 of Set 10 | aldan
# Processing Record 39 of Set 10 | sentyabrskiy
# City not found. Skipping.....
# Processing Record 40 of Set 10 | nefteyugansk
# Processing Record 41 of Set 10 | ayan
# Processing Record 42 of Set 10 | mrirt
# City not found. Skipping.....
# Processing Record 43 of Set 10 | fortuna
# Processing Record 44 of Set 10 | covington
# Processing Record 45 of Set 10 | gamba
# Processing Record 46 of Set 10 | samalaeulu
# City not found. Skipping.....
# Processing Record 47 of Set 10 | pasighat
# Processing Record 48 of Set 10 | harper
# Processing Record 49 of Set 10 | buchanan
# Processing Record 50 of Set 10 | qaqortoq
# Processing Record 1 of Set 11 | uthal
# Processing Record 2 of Set 11 | nove straseci
# Processing Record 3 of Set 11 | tazovskiy
# Processing Record 4 of Set 11 | naze
# Processing Record 5 of Set 11 | jhol
# Processing Record 6 of Set 11 | liminangcong
# City not found. Skipping.....
# Processing Record 7 of Set 11 | louisbourg
# City not found. Skipping.....
# Processing Record 8 of Set 11 | huarmey
# Processing Record 9 of Set 11 | faya
# Processing Record 10 of Set 11 | mokolo
# Processing Record 11 of Set 11 | hobyo
# Processing Record 12 of Set 11 | vardo
# Processing Record 13 of Set 11 | khandyga
# Processing Record 14 of Set 11 | mount gambier
# Processing Record 15 of Set 11 | shelburne
# Processing Record 16 of Set 11 | yandoon
# City not found. Skipping.....
# Processing Record 17 of Set 11 | port moresby
# Processing Record 18 of Set 11 | letterkenny
# Processing Record 19 of Set 11 | nichinan
# Processing Record 20 of Set 11 | mugur-aksy
# Processing Record 21 of Set 11 | galatista
# Processing Record 22 of Set 11 | salsomaggiore terme
# Processing Record 23 of Set 11 | iskateley
# Processing Record 24 of Set 11 | san luis
# Processing Record 25 of Set 11 | basco
# Processing Record 26 of Set 11 | ilulissat
# Processing Record 27 of Set 11 | miguel auza
# Processing Record 28 of Set 11 | mao
# Processing Record 29 of Set 11 | mogadishu
# Processing Record 30 of Set 11 | sorvag
# City not found. Skipping.....
# Processing Record 31 of Set 11 | george
# Processing Record 32 of Set 11 | toppenish
# Processing Record 33 of Set 11 | katobu
# Processing Record 34 of Set 11 | ellwangen
# Processing Record 35 of Set 11 | mandalgovi
# Processing Record 36 of Set 11 | te anau
# Processing Record 37 of Set 11 | marcona
# City not found. Skipping.....
# Processing Record 38 of Set 11 | graaff-reinet
# Processing Record 39 of Set 11 | kisangani
# Processing Record 40 of Set 11 | pekan
# Processing Record 41 of Set 11 | korem
# Processing Record 42 of Set 11 | saint-augustin
# Processing Record 43 of Set 11 | lodja
# Processing Record 44 of Set 11 | chagda
# City not found. Skipping.....
# Processing Record 45 of Set 11 | mazagao
# Processing Record 46 of Set 11 | ribeira brava
# Processing Record 47 of Set 11 | kallithea
# Processing Record 48 of Set 11 | omboue
# Processing Record 49 of Set 11 | orlik
# Processing Record 50 of Set 11 | hofn
# Processing Record 1 of Set 12 | nador
# Processing Record 2 of Set 12 | axim
# Processing Record 3 of Set 12 | dzhusaly
# City not found. Skipping.....
# Processing Record 4 of Set 12 | sudbury
# Processing Record 5 of Set 12 | makat
# Processing Record 6 of Set 12 | bambous virieux
# Processing Record 7 of Set 12 | jimo
# Processing Record 8 of Set 12 | constitucion
# Processing Record 9 of Set 12 | saldanha
# Processing Record 10 of Set 12 | lincoln
# Processing Record 11 of Set 12 | talnakh
# Processing Record 12 of Set 12 | kutum
# Processing Record 13 of Set 12 | dagua
# Processing Record 14 of Set 12 | los llanos de aridane
# Processing Record 15 of Set 12 | beloha
# Processing Record 16 of Set 12 | lorengau
# Processing Record 17 of Set 12 | tailai
# Processing Record 18 of Set 12 | tunduma
# Processing Record 19 of Set 12 | nadadores
# Processing Record 20 of Set 12 | tongliao
# Processing Record 21 of Set 12 | samarai
# Processing Record 22 of Set 12 | healdsburg
# Processing Record 23 of Set 12 | kuryk
# Processing Record 24 of Set 12 | bansang
# Processing Record 25 of Set 12 | sovetskiy
# Processing Record 26 of Set 12 | yulara
# Processing Record 27 of Set 12 | shingu
# Processing Record 28 of Set 12 | dvinskoy
# Processing Record 29 of Set 12 | am timan
# Processing Record 30 of Set 12 | vaitupu
# City not found. Skipping.....
# Processing Record 31 of Set 12 | mundra
# Processing Record 32 of Set 12 | abu dhabi
# Processing Record 33 of Set 12 | capao da canoa
# Processing Record 34 of Set 12 | pundaguitan
# Processing Record 35 of Set 12 | chicama
# Processing Record 36 of Set 12 | akdepe
# Processing Record 37 of Set 12 | port said
# Processing Record 38 of Set 12 | karaul
# City not found. Skipping.....
# Processing Record 39 of Set 12 | russell
# Processing Record 40 of Set 12 | mazatlan
# Processing Record 41 of Set 12 | honiara
# Processing Record 42 of Set 12 | mlonggo
# Processing Record 43 of Set 12 | nantucket
# Processing Record 44 of Set 12 | kungurtug
# Processing Record 45 of Set 12 | coolum beach
# Processing Record 46 of Set 12 | kirakira
# Processing Record 47 of Set 12 | lakes entrance
# Processing Record 48 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 12 | hidalgo
# Processing Record 50 of Set 12 | valparaiso
# Processing Record 1 of Set 13 | liverpool
# Processing Record 2 of Set 13 | abbeville
# Processing Record 3 of Set 13 | port pirie
# Processing Record 4 of Set 13 | gouyave
# Processing Record 5 of Set 13 | bud
# Processing Record 6 of Set 13 | dunedin
# Processing Record 7 of Set 13 | santa rosa
# Processing Record 8 of Set 13 | fort frances
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Pevek  69.7008  170.3133     -8.54        91         100
# 1          Bluff -46.6000  168.3333     60.69        92          91
# 2  Cockburn Town  21.4612  -71.1419     79.32        76          29
# 3        Wasilla  61.5814 -149.4394      4.75        83           1
# 4         Broome  42.2506  -75.8330     33.84        72          90
# 5          Tiksi  71.6872  128.8694    -31.34        99          42
# 6           Lasa  46.6166   10.7002     30.94        66         100
# 7        Rikitea -23.1203 -134.9692     76.73        73          61
# 8       Villazon -22.0866  -65.5942     52.43        67         100
# 9     San Andres  12.5847  -81.7006     82.42        83          75
#
#    Wind Speed Country                date
# 0       13.00      RU  2021-1204 03:15:56
# 1        5.37      NZ  2021-1204 03:15:56
# 2       16.82      TC  2021-1204 03:15:56
# 3        0.00      US  2021-1204 03:15:57
# 4        3.00      US  2021-1204 03:15:57
# 5        5.50      RU  2021-1204 03:15:57
# 6        3.22      IT  2021-1204 03:15:58
# 7       15.64      PF  2021-1204 03:15:58
# 8        7.36      BO  2021-1204 03:15:58
# 9       11.50      CO  2021-1204 03:15:59

# %%
new_column_order = ['City', 'Country', 'date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df.head(15)
# Out:
#              City Country                date      Lat       Lng  Max Temp  \
# 0           Pevek      RU  2021-1204 03:15:56  69.7008  170.3133     -8.54
# 1           Bluff      NZ  2021-1204 03:15:56 -46.6000  168.3333     60.69
# 2   Cockburn Town      TC  2021-1204 03:15:56  21.4612  -71.1419     79.32
# 3         Wasilla      US  2021-1204 03:15:57  61.5814 -149.4394      4.75
# 4          Broome      US  2021-1204 03:15:57  42.2506  -75.8330     33.84
# 5           Tiksi      RU  2021-1204 03:15:57  71.6872  128.8694    -31.34
# 6            Lasa      IT  2021-1204 03:15:58  46.6166   10.7002     30.94
# 7         Rikitea      PF  2021-1204 03:15:58 -23.1203 -134.9692     76.73
# 8        Villazon      BO  2021-1204 03:15:58 -22.0866  -65.5942     52.43
# 9      San Andres      CO  2021-1204 03:15:59  12.5847  -81.7006     82.42
# 10   Puerto Ayora      EC  2021-1204 03:15:59  -0.7393  -90.3518     67.64
# 11    East London      ZA  2021-1204 03:15:59 -33.0153   27.9116     65.34
# 12       Dreznica      BA  2021-1204 03:16:00  43.5289   17.2819     33.22
# 13  Saint Anthony      US  2021-1204 03:15:32  45.0205  -93.2180     35.26
# 14          Jumla      NP  2021-1204 03:15:04  29.2747   82.1838     48.34
#
#     Humidity  Cloudiness  Wind Speed
# 0         91         100       13.00
# 1         92          91        5.37
# 2         76          29       16.82
# 3         83           1        0.00
# 4         72          90        3.00
# 5         99          42        5.50
# 6         66         100        3.22
# 7         73          61       15.64
# 8         67         100        7.36
# 9         83          75       11.50
# 10        92          60        5.95
# 11        88          20        1.14
# 12        80           8        6.02
# 13        79           1        1.99
# 14        62           4        4.00

# %%
import os
cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in '/Users/armandolatigo/Desktop/Analysis Projects/World_Weather_Analysis2': ['.DS_Store', 'config.py', '__pycache__', 'README.md', 'random_numbers.ipynb', '.gitignore', 'weather_data', 'WeatherPy.ipynb', '.ipynb_checkpoints', '.git', 'API_Practice.ipynb']

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
